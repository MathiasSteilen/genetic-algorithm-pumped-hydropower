# %% [markdown]
# # Pumped-Storage Optimisation with Genetic Algorithm and MILP

# %%
import pandas as pd
import datetime
import numpy as np
import plotnine as pn
import plotly.graph_objs as go
import plotly.express as px
from tqdm.notebook import tqdm
from IPython.display import clear_output, display
import os
from itertools import product

# Import own implementations
from milp import MILP
import genetic_numpy
from genetic_numpy import GA_discrete_actions, evaluate_fitness

# Importing tuning libraries
import ray
from ray import train, tune
from ray.tune.search.optuna import OptunaSearch
from ray.tune.schedulers import ASHAScheduler

background_colour = "#F2F2F2"
pn.theme_set(
    pn.theme_classic()
    + pn.theme(
        text=pn.element_text(family="monospace"),
        plot_background=pn.element_rect(
            fill=background_colour, colour=background_colour
        ),
        panel_background=pn.element_rect(
            fill=background_colour, colour=background_colour
        ),
        legend_background=pn.element_rect(
            fill=background_colour, colour=background_colour
        ),
    )
)

# %load_ext blackcellmagic
# Out:
# The blackcellmagic extension is already loaded. To reload it, use:
#   %reload_ext blackcellmagic

# %% [markdown]
# ## Reading the Price data

# %%
df = pd.read_csv("../01 - Data/example_week.csv")
df.head(2)
# Out:
#      spot                   utc_time
# 0  101.54  2022-01-01 00:00:00+00:00
# 1   52.13  2022-01-01 01:00:00+00:00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   spot      168 non-null    float64
#  1   utc_time  168 non-null    object
# dtypes: float64(1), object(1)
# memory usage: 2.8+ KB

# %% [markdown]
# ## The Power Plant

# %%
plant_params = {
    "EFFICIENCY": 0.75,
    "MAX_STORAGE_M3": 5000,
    "MIN_STORAGE_M3": 0,
    "TURBINE_POWER_MW": 100,
    "PUMP_POWER_MW": 100,
    "TURBINE_RATE_M3H": 500,
    "MIN_STORAGE_MWH": 0,
    "INITIAL_WATER_LEVEL_PCT": 0,
}
plant_params["INITIAL_WATER_LEVEL"] = (
    plant_params["INITIAL_WATER_LEVEL_PCT"] * plant_params["MAX_STORAGE_M3"]
)
plant_params["PUMP_RATE_M3H"] = (
    plant_params["TURBINE_RATE_M3H"] * plant_params["EFFICIENCY"]
)
plant_params["MAX_STORAGE_MWH"] = (
    plant_params["MAX_STORAGE_M3"] / plant_params["TURBINE_RATE_M3H"]
) * plant_params["TURBINE_POWER_MW"]

# %% [markdown]
# ## GA

# %%
ga_solver = GA_discrete_actions(
    plant_params=plant_params, spot=df["spot"], utc_time=df["utc_time"], actions_space= [-1, 0, 1]
)

# %%
analysis = ga_solver.tune(
    tune_config={
        "POP_SIZE": 500,
        "INITIAL_MUTATION_RATE": tune.uniform(0.05, 0.75),
        "FINAL_MUTATION_RATE": tune.uniform(0.001, 0.2),
        "MUTATION_ELEMENTS": tune.randint(1, df.shape[0]),
        "INITIAL_EXPLORATION": tune.uniform(0.05, 0.95),
        "ELITISM": tune.uniform(0.05, 0.95),
        "SURVIVAL_RATE": tune.uniform(0.05, 0.95),
    },
    total_generations=500,
    timeout_s=60*60*10,
)
# Out:
# 2024-04-12 23:07:16,558	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# 2024-04-12 23:07:16,710	INFO packaging.py:530 -- Creating a file package for local directory '.'.
# 2024-04-12 23:07:16,715	WARNING packaging.py:405 -- File c:\Users\STEIM\OneDrive - BKW\Dokumente\ETH\genetic-algorithm-pumped-hydropower\05 - Part 1 Deterministic Actions\Actions Tuning.ipynb is very large (11.42MiB). Consider adding this file to the 'excludes' list to skip uploading it: `ray.init(..., runtime_env={'excludes': ['c:\Users\STEIM\OneDrive - BKW\Dokumente\ETH\genetic-algorithm-pumped-hydropower\05 - Part 1 Deterministic Actions\Actions Tuning.ipynb']})`
# 2024-04-12 23:07:16,747	WARNING packaging.py:405 -- File c:\Users\STEIM\OneDrive - BKW\Dokumente\ETH\genetic-algorithm-pumped-hydropower\05 - Part 1 Deterministic Actions\Tuning Results\202404111039_GA_Elite.csv is very large (34.73MiB). Consider adding this file to the 'excludes' list to skip uploading it: `ray.init(..., runtime_env={'excludes': ['c:\Users\STEIM\OneDrive - BKW\Dokumente\ETH\genetic-algorithm-pumped-hydropower\05 - Part 1 Deterministic Actions\Tuning Results\202404111039_GA_Elite.csv']})`
# 2024-04-12 23:07:16,820	WARNING packaging.py:405 -- File c:\Users\STEIM\OneDrive - BKW\Dokumente\ETH\genetic-algorithm-pumped-hydropower\05 - Part 1 Deterministic Actions\Tuning Results\202404111525_GA_Tournament.csv is very large (21.52MiB). Consider adding this file to the 'excludes' list to skip uploading it: `ray.init(..., runtime_env={'excludes': ['c:\Users\STEIM\OneDrive - BKW\Dokumente\ETH\genetic-algorithm-pumped-hydropower\05 - Part 1 Deterministic Actions\Tuning Results\202404111525_GA_Tournament.csv']})`
# 2024-04-12 23:07:16,863	WARNING packaging.py:405 -- File c:\Users\STEIM\OneDrive - BKW\Dokumente\ETH\genetic-algorithm-pumped-hydropower\05 - Part 1 Deterministic Actions\Tuning Results\202404120310_GA_Elite.csv is very large (39.83MiB). Consider adding this file to the 'excludes' list to skip uploading it: `ray.init(..., runtime_env={'excludes': ['c:\Users\STEIM\OneDrive - BKW\Dokumente\ETH\genetic-algorithm-pumped-hydropower\05 - Part 1 Deterministic Actions\Tuning Results\202404120310_GA_Elite.csv']})`
# 2024-04-12 23:07:16,951	WARNING packaging.py:405 -- File c:\Users\STEIM\OneDrive - BKW\Dokumente\ETH\genetic-algorithm-pumped-hydropower\05 - Part 1 Deterministic Actions\Tuning Results\202404120811_GA_Tournament.csv is very large (49.79MiB). Consider adding this file to the 'excludes' list to skip uploading it: `ray.init(..., runtime_env={'excludes': ['c:\Users\STEIM\OneDrive - BKW\Dokumente\ETH\genetic-algorithm-pumped-hydropower\05 - Part 1 Deterministic Actions\Tuning Results\202404120811_GA_Tournament.csv']})`
# 2024-04-12 23:07:17,100	INFO packaging.py:358 -- Pushing file package 'gcs://_ray_pkg_0eabd2fa5445a584.zip' (158.53MiB) to Ray cluster...
# 2024-04-12 23:07:17,546	INFO packaging.py:371 -- Successfully pushed file package 'gcs://_ray_pkg_0eabd2fa5445a584.zip'.
# 2024-04-12 23:07:19,296	INFO tune.py:613 -- [output] This uses the legacy output and progress reporter, as Jupyter notebooks are not supported by the new engine, yet. For more information, please see https://github.com/ray-project/ray/issues/36949
# [I 2024-04-12 23:07:19,302] A new study created in memory with name: optuna
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-04-13 09:07:33</td></tr>
# <tr><td>Running for: </td><td>10:00:13.94        </td></tr>
# <tr><td>Memory:      </td><td>28.5/31.6 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 28.0/28 CPUs, 0/1 GPUs (0.0/1.0 accelerator_type:RTX)
#     </div>
#     <div class="vDivider"></div>
# <div class="messages">
#   <h3>Messages</h3>
#   : ***LOW MEMORY*** less than 10% of the memory on this node is available for use. This can cause unexpected crashes. Consider reducing the memory used by your application or reducing the Ray object store size by setting `object_store_memory` when calling `ray.init`.
#
#
# </div>
# <style>
# .messages {
#   color: var(--jp-ui-font-color1);
#   display: flex;
#   flex-direction: column;
#   padding-left: 1em;
#   overflow-y: auto;
# }
# .messages h3 {
#   font-weight: bold;
# }
# .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name    </th><th>status    </th><th>loc            </th><th style="text-align: right;">  ELITISM</th><th style="text-align: right;">  FINAL_MUTATION_RATE</th><th style="text-align: right;">  INITIAL_EXPLORATION</th><th style="text-align: right;">          INITIAL_MUTATION_RAT
# E</th><th style="text-align: right;">  MUTATION_ELEMENTS</th><th style="text-align: right;">  SURVIVAL_RATE</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  fitness</th></tr>
# </thead>
# <tbody>
# <tr><td>train_684066e2</td><td>TERMINATED</td><td>127.0.0.1:26100</td><td style="text-align: right;">0.745094 </td><td style="text-align: right;">           0.0879389 </td><td style="text-align: right;">            0.462929 </td><td style="text-align: right;">0.579102 </td><td style="text-align: right;">                 28</td><td style="text-align: right;">      0.344975 </td><td style="text-align: right;">   500</td><td style="text-align: right;">        14.6809 </td><td style="text-align: right;"> 304432  </td></tr>
# <tr><td>train_5fdb77db</td><td>TERMINATED</td><td>127.0.0.1:29900</td><td style="text-align: right;">0.167684 </td><td style="text-align: right;">           0.078146  </td><td style="text-align: right;">            0.691451 </td><td style="text-align: right;">0.587181 </td><td style="text-align: right;">                 31</td><td style="text-align: right;">      0.240145 </td><td style="text-align: right;">   500</td><td style="text-align: right;">        14.406  </td><td style="text-align: right;"> 185488  </td></tr>
# <tr><td>train_d3e28fd6</td><td>TERMINATED</td><td>127.0.0.1:22908</td><td style="text-align: right;">0.26929  </td><td style="text-align: right;">           0.0468079 </td><td style="text-align: right;">            0.434343 </td><td style="text-align: right;">0.209145 </td><td style="text-align: right;">                111</td><td style="text-align: right;">      0.885666 </td><td style="text-align: right;">   500</td><td style="text-align: right;">         9.41649</td><td style="text-align: right;"> 212556  </td></tr>
# <tr><td>train_23d27001</td><td>TERMINATED</td><td>127.0.0.1:27956</td><td style="text-align: right;">0.142691 </td><td style="text-align: right;">           0.0439637 </td><td style="text-align: right;">            0.316495 </td><td style="text-align: right;">0.571381 </td><td style="text-align: right;">                 14</td><td style="text-align: right;">      0.259208 </td><td style="text-align: right;">   500</td><td style="text-align: right;">        14.9287 </td><td style="text-align: right;"> 218142  </td></tr>
# <tr><td>train_4f65b3b6</td><td>TERMINATED</td><td>127.0.0.1:26072</td><td style="text-align: right;">0.437571 </td><td style="text-align: right;">           0.0556417 </td><td style="text-align: right;">            0.122164 </td><td style="text-align: right;">0.413038 </td><td style="text-align: right;">                 31</td><td style="text-align: right;">      0.561952 </td><td style="text-align: right;">   500</td><td style="text-align: right;">        13.0362 </td><td style="text-align: right;"> 231099  </td></tr>
# <tr><td>train_17a494de</td><td>TERMINATED</td><td>127.0.0.1:27192</td><td style="text-align: right;">0.262375 </td><td style="text-align: right;">           0.00927095</td><td style="text-align: right;">            0.254692 </td><td style="text-align: right;">0.140373 </td><td style="text-align: right;">                 91</td><td style="text-align: right;">      0.468229 </td><td style="text-align: right;">   500</td><td style="text-align: right;">        13.2536 </td><td style="text-align: right;"> 224332  </td></tr>
# <tr><td>train_1c0986d9</td><td>TERMINATED</td><td>127.0.0.1:9900 </td><td style="text-align: right;">0.840941 </td><td style="text-align: right;">           0.0988691 </td><td style="text-align: right;">            0.216339 </td><td style="text-align: right;">0.174536 </td><td style="text-align: right;">                153</td><td style="text-align: right;">      0.639452 </td><td style="text-align: right;">   500</td><td style="text-align: right;">        13.3303 </td><td style="text-align: right;"> 274404  </td></tr>
# <tr><td>train_b84c3f9c</td><td>TERMINATED</td><td>127.0.0.1:3396 </td><td style="text-align: right;">0.363476 </td><td style="text-align: right;">           0.00686722</td><td style="text-align: right;">            0.503902 </td><td style="text-align: right;">0.665451 </td><td style="text-align: right;">                 73</td><td style="text-align: right;">      0.463398 </td><td style="text-align: right;">   500</td><td style="text-align: right;">        14.2841 </td><td style="text-align: right;"> 277402  </td></tr>
# <tr><td>train_9c00022a</td><td>TERMINATED</td><td>127.0.0.1:29548</td><td style="text-align: right;">0.397092 </td><td style="text-align: right;">           0.15351   </td><td style="text-align: right;">            0.763624 </td><td style="text-align: right;">0.613812 </td><td style="text-align: right;">                  3</td><td style="text-align: right;">      0.80367  </td><td style="text-align: right;">   500</td><td style="text-align: right;">        13.4004 </td><td style="text-align: right;"> 290774  </td></tr>
# <tr><td>train_ce60a044</td><td>TERMINATED</td><td>127.0.0.1:21264</td><td style="text-align: right;">0.45801  </td><td style="text-align: right;">           0.12922   </td><td style="text-align: right;">            0.0955214</td><td style="text-align: right;">0.562066 </td><td style="text-align: right;">                 71</td><td style="text-align: right;">      0.55561  </td><td style="text-align: right;">   500</td><td style="text-align: right;">        13.4462 </td><td style="text-align: right;"> 228825  </td></tr>
# <tr><td>train_215923d9</td><td>TERMINATED</td><td>127.0.0.1:33376</td><td style="text-align: right;">0.358439 </td><td style="text-align: right;">           0.0344492 </td><td style="text-align: right;">            0.656919 </td><td style="text-align: right;">0.629934 </td><td style="text-align: right;">                130</td><td style="text-align: right;">      0.620763 </td><td style="text-align: right;">   500</td><td style="text-align: right;">        13.6584 </td><td style="text-align: right;"> 287569  </td></tr>
# <tr><td>train_285129ce</td><td>TERMINATED</td><td>127.0.0.1:5036 </td><td style="text-align: right;">0.708937 </td><td style="text-align: right;">           0.0733522 </td><td style="text-align: right;">            0.220343 </
# <div class="trialProgress">
#   <h3>Trial Progress</h3>
#   <table>
# <thead>
# <tr><th>Trial name    </th><th style="text-align: right;">  fitness</th></tr>
# </thead>
# <tbody>
# <tr><td>train_00146635</td><td style="text-align: right;"> 318060  </td></tr>
# <tr><td>train_002a98f8</td><td style="text-align: right;">  71882.5</td></tr>
# <tr><td>train_003c4739</td><td style="text-align: right;"> 277504  </td></tr>
# <tr><td>train_0058867e</td><td style="text-align: right;"> 303701  </td></tr>
# <tr><td>train_005b7357</td><td style="text-align: right;"> 317230  </td></tr>
# <tr><td>train_00947315</td><td style="text-align: right;"> 316913  </td></tr>
# <tr><td>train_00c89730</td><td style="text-align: right;"> 319901  </td></tr>
# <tr><td>train_00ce1fbf</td><td style="text-align: right;"> 321235  </td></tr>
# <tr><td>train_00dab921</td><td style="text-align: right;"> 317034  </td></tr>
# <tr><td>train_00dc196f</td><td style="text-align: right;"> 321211  </td></tr>
# <tr><td>train_00deec9d</td><td style="text-align: right;"> 305431  </td></tr>
# <tr><td>train_00f21f51</td><td style="text-align: right;"> 322775  </td></tr>
# <tr><td>train_00f9f3f3</td><td style="text-align: right;"> 316387  </td></tr>
# <tr><td>train_01098489</td><td style="text-align: right;"> 314128  </td></tr>
# <tr><td>train_0112b656</td><td style="text-align: right;"> 317456  </td></tr>
# <tr><td>train_0112e093</td><td style="text-align: right;"> 320362  </td></tr>
# <tr><td>train_011aa9dc</td><td style="text-align: right;"> 296074  </td></tr>
# <tr><td>train_01483566</td><td style="text-align: right;"> 292517  </td></tr>
# <tr><td>train_0157e283</td><td style="text-align: right;"> 317888  </td></tr>
# <tr><td>train_015a8bf9</td><td style="text-align: right;"> 319675  </td></tr>
# <tr><td>train_016c8aa5</td><td style="text-align: right;"> 304231  </td></tr>
# <tr><td>train_01b87009</td><td style="text-align: right;"> 318470  </td></tr>
# <tr><td>train_01d2d91a</td><td style="text-align: right;"> 318005  </td></tr>
# <tr><td>train_01d712e2</td><td style="text-align: right;"> 275102  </td></tr>
# <tr><td>train_01df3c41</td><td style="text-align: right;"> 318234  </td></tr>
# <tr><td>train_01eb1e8b</td><td style="text-align: right;"> 315866  </td></tr>
# <tr><td>train_0208143a</td><td style="text-align: right;"> 304241  </td></tr>
# <tr><td>train_021f53cf</td><td style="text-align: right;"> 321851  </td></tr>
# <tr><td>train_0229bf34</td><td style="text-align: right;"> 320074  </td></tr>
# <tr><td>train_022f60d7</td><td style="text-align: right;"> 315237  </td></tr>
# <tr><td>train_02660c7d</td><td style="text-align: right;"> 318034  </td></tr>
# <tr><td>train_02696ce7</td><td style="text-align: right;"> 316523  </td></tr>
# <tr><td>train_02839662</td><td style="text-align: right;"> 317131  </td></tr>
# <tr><td>train_029201e7</td><td style="text-align: right;"> 317722  </td></tr>
# <tr><td>train_0294d17a</td><td style="text-align: right;"> 311061  </td></tr>
# <tr><td>train_02b1db7a</td><td style="text-align: right;"> 319404  </td></tr>
# <tr><td>train_02b56a36</td><td style="text-align: right;"> 314514  </td></tr>
# <tr><td>train_02beebbb</td><td style="text-align: right;"> 306204  </td></tr>
# <tr><td>train_02ce2231</td><td style="text-align: right;"> 315784  </td></tr>
# <tr><td>train_02cf4519</td><td style="text-align: right;"> 318318  </td></tr>
# <tr><td>train_02dc9515</td><td style="text-align: right;"> 311577  </td></tr>
# <tr><td>train_02ed08c1</td><td style="text-align: right;"> 317321  </td></tr>
# <tr><td>train_02eea6ae</td><td style="text-align: right;"> 315319  </td></tr>
# <tr><td>train_02fe1de1</td><td style="text-align: right;"> 319080  </td></tr>
# <tr><td>train_03313e9c</td><td style="text-align: right;"> 316842  </td></tr>
# <tr><td>train_03507d2c</td><td style="text-align: right;"> 320348  </td></tr>
# <tr><td>train_035b099b</td><td style="text-align: right;"> 318002  </td></tr>
# <tr><td>train_035f7499</td><td style="text-align: right;"> 326435  </td></tr>
# <tr><td>train_037b908d</td><td style="text-align: right;"> 304492  </td></tr>
# <tr><td>train_03a6d21d</td><td style="text-align: right;"> 322336  </td></tr>
# <tr><td>train_03c433b1</td><td style="text-align: right;"> 303819  </td></tr>
# <tr><td>train_03c5e16b</td><td style="text-align: right;"> 321470  </td></tr>
# <tr><td>train_03cf566f</td><td style="text-align: right;"> 314055  </td></tr>
# <tr><td>train_03d52096</td><td style="text-align: right;"> 314557  </td></tr>
# <tr><td>train_0405d750</td><td style="text-align: right;"> 316838  </td></tr>
# <tr><td>train_0417f7b5</td><td style="text-align: right;"> 306418  </td></tr>
# <tr><td>train_0428c908</td><td style="text-align: right;"> 312205  </td></tr>
# <tr><td>train_042eff1e</td><td style="text-align: right;"> 318475  </td></tr>
# <tr><td>train_046da608</td><td style="text-align: right;"> 306088  </td></tr>
# <tr><td>train_0476e9a8</td><td style="text-align: right;"> 317662  </td></tr>
# <tr><td>train_048241d6</td><td style="text-align: right;"> 157363  </td></tr>
# <tr><td>train_049498e8</td><td style="text-align: right;"> 320702  </td></tr>
# <tr><td>train_0498d3ea</td><td style="text-align: right;"> 314830  </td></tr>
# <tr><td>train_04bb714a</td><td style="text-align: right;"> 316729  </td></tr>
# <tr><td>train_04bc7f28</td><td style="text-align: right;"> 319232  </td></tr>
# <tr><td>train_04bde3ce</td><td style="text-align: right;"> 301767  </td></tr>
# <tr><td>train_04c1c4b5</td><td style="text-align: right;"> 318574  </td></tr>
# <tr><td>train_04c5507a</td><td style="text-align: right;"> 321288  </td></tr>
# <tr><td>train_04efde64</td><td style="text-align: right;"> 312353  </td></tr>
# <tr><td>train_0505f500</td><td style="text-align: right;"> 314845  </td></tr>
# <tr><td>train_0508f9ad</td><td style="text-align: right;"> 315002  </td></tr>
# <tr><td>train_050aa5ed</td><td style="text-align: right;"> 321017  </td></tr>
# <tr><td>train_051171cd</td><td style="text-align: right;"> 315453  </td></tr>
# <tr><td>train_051880f1</td><td style="text-align: right;"> 313667  </td></tr>
# <tr><td>train_051ae4b7</td><td style="text-align: right;"> 304981  </td></tr>
# <tr><td>train_05211ab5</td><td style="text-align: right;"> 318738  </td></tr>
# <tr><td>train_0523a763</td><td style="text-align: right;"> 308178  </td></tr>
# <tr><td>train_05280114</td><td style="text-align: right;"> 319456  </td></tr>
# <tr><td>train_05315ce2</td><td style="text-align: right;"> 320916  </td></tr>
# <tr><td>train_054422f0</td><td style="text-align: right;"> 319202  </td></tr>
# <tr><td>train_05513213</td><td style="text-align: right;"> 324768  </td></tr>
# <tr><td>train_0567b948</td><td style="text-align: right;"> 302872  </td></tr>
# <tr><td>train_057c98e6</td><td style="text-align: right;"> 303023  </td></tr>
# <tr><td>train_05aa1826</td><td style="text-align: right;"> 292488  </td></tr>
# <tr><td>train_05e5e552</td><td style="text-align: right;"> 271328  </td></tr>
# <tr><td>train_063f0c54</td><td style="text-align: right;"> 307735  </td></tr>
# <tr><td>train_0640463c</td><td style="text-align: right;"> 322882  </td></tr>
# <tr><td>train_064ac80e</td><td style="text-align: right;"> 306986  </td></tr>
# <tr><td>train_0653ec4e</td><td style="text-align: right;"> 318214  </td></tr>
# <tr><td>train_065d05d2</td><td style="text-align: right;"> 301472  </td></tr>
# <tr><td>train_0679b422</td><td style="text-align: right;"> 320248  </td></tr>
# <tr><td>train_068f98df</td><td style="text-align: right;"> 293017  </td></tr>
# <tr><td>train_0690c682</td><td style="text-align: right;"> 301833  </td></tr>
# <tr><td>train_06c38cf1</td><td style="text-align: right;"> 318319  </td></tr>
# <tr><td>train_06c529c7</td><td style="text-align: right;"> 295828  </td></tr>
# <tr><td>train_06e455a6</td><td style="text-align: right;"> 320479  </td></tr>
# <tr><td>train_06e53b53</td><td style="text-align: right;"> 313742  </td></tr>
# <tr><td>train_06f44ee7</td><td style="text-align: right;"> 322600  </td></tr>
# <tr><td>train_0709834b</td><td style="text-align: right;"> 314550  </td></tr>
# <tr><td>train_071073ec</td><td style="text-align: right;"> 320203  </td></tr>
# <tr><td>train_071196a9</td><td st
# 2024-04-12 23:09:41,626	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.896 s, which may be a performance bottleneck.
# 2024-04-12 23:09:41,629	WARNING util.py:202 -- The `process_trial_result` operation took 0.898 s, which may be a performance bottleneck.
# 2024-04-12 23:09:41,629	WARNING util.py:202 -- Processing trial results took 0.899 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-12 23:09:41,630	WARNING util.py:202 -- The `process_trial_result` operation took 0.900 s, which may be a performance bottleneck.
# 2024-04-12 23:34:10,131	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.943 s, which may be a performance bottleneck.
# 2024-04-12 23:34:10,133	WARNING util.py:202 -- The `process_trial_result` operation took 0.945 s, which may be a performance bottleneck.
# 2024-04-12 23:34:10,134	WARNING util.py:202 -- Processing trial results took 0.946 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-12 23:34:10,134	WARNING util.py:202 -- The `process_trial_result` operation took 0.946 s, which may be a performance bottleneck.
# (train pid=18852)
# (train pid=18852)
# 2024-04-13 04:07:41,745	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.523 s, which may be a performance bottleneck.
# 2024-04-13 04:07:41,747	WARNING util.py:202 -- The `process_trial_result` operation took 0.525 s, which may be a performance bottleneck.
# 2024-04-13 04:07:41,749	WARNING util.py:202 -- Processing trial results took 0.527 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 04:07:41,750	WARNING util.py:202 -- The `process_trial_result` operation took 0.528 s, which may be a performance bottleneck.
# 2024-04-13 04:19:20,089	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.528 s, which may be a performance bottleneck.
# 2024-04-13 04:19:20,091	WARNING util.py:202 -- The `process_trial_result` operation took 0.530 s, which may be a performance bottleneck.
# 2024-04-13 04:19:20,092	WARNING util.py:202 -- Processing trial results took 0.531 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 04:19:20,094	WARNING util.py:202 -- The `process_trial_result` operation took 0.533 s, which may be a performance bottleneck.
# 2024-04-13 04:35:32,611	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.501 s, which may be a performance bottleneck.
# 2024-04-13 04:35:32,613	WARNING util.py:202 -- The `process_trial_result` operation took 0.503 s, which may be a performance bottleneck.
# 2024-04-13 04:35:32,614	WARNING util.py:202 -- Processing trial results took 0.504 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 04:35:32,616	WARNING util.py:202 -- The `process_trial_result` operation took 0.505 s, which may be a performance bottleneck.
# 2024-04-13 04:45:41,787	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.503 s, which may be a performance bottleneck.
# 2024-04-13 04:45:41,789	WARNING util.py:202 -- The `process_trial_result` operation took 0.505 s, which may be a performance bottleneck.
# 2024-04-13 04:45:41,790	WARNING util.py:202 -- Processing trial results took 0.506 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 04:45:41,791	WARNING util.py:202 -- The `process_trial_result` operation took 0.507 s, which may be a performance bottleneck.
# 2024-04-13 04:46:42,619	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.523 s, which may be a performance bottleneck.
# 2024-04-13 04:46:42,621	WARNING util.py:202 -- The `process_trial_result` operation took 0.525 s, which may be a performance bottleneck.
# 2024-04-13 04:46:42,623	WARNING util.py:202 -- Processing trial results took 0.527 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 04:46:42,624	WARNING util.py:202 -- The `process_trial_result` operation took 0.528 s, which may be a performance bottleneck.
# 2024-04-13 04:48:21,848	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.500 s, which may be a performance bottleneck.
# 2024-04-13 04:48:21,850	WARNING util.py:202 -- The `process_trial_result` operation took 0.502 s, which may be a performance bottleneck.
# 2024-04-13 04:48:21,851	WARNING util.py:202 -- Processing trial results took 0.503 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 04:48:21,852	WARNING util.py:202 -- The `process_trial_result` operation took 0.504 s, which may be a performance bottleneck.
# 2024-04-13 04:52:04,251	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.514 s, which may be a performance bottleneck.
# 2024-04-13 04:52:04,254	WARNING util.py:202 -- The `process_trial_result` operation took 0.517 s, which may be a performance bottleneck.
# 2024-04-13 04:52:04,255	WARNING util.py:202 -- Processing trial results took 0.518 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 04:52:04,257	WARNING util.py:202 -- The `process_trial_result` operation took 0.519 s, which may be a performance bottleneck.
# (train pid=24432)
# 2024-04-13 04:54:12,568	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.518 s, which may be a performance bottleneck.
# 2024-04-13 04:54:12,571	WARNING util.py:202 -- The `process_trial_result` operation took 0.521 s, which may be a performance bottleneck.
# 2024-04-13 04:54:12,572	WARNING util.py:202 -- Processing trial results took 0.522 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 04:54:12,573	WARNING util.py:202 -- The `process_trial_result` operation took 0.523 s, which may be a performance bottleneck.
# 2024-04-13 04:54:34,309	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.509 s, which may be a performance bottleneck.
# 2024-04-13 04:54:34,312	WARNING util.py:202 -- The `process_trial_result` operation took 0.512 s, which may be a performance bottleneck.
# 2024-04-13 04:54:34,314	WARNING util.py:202 -- Processing trial results took 0.514 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 04:54:34,315	WARNING util.py:202 -- The `process_trial_result` operation took 0.515 s, which may be a performance bottleneck.
# 2024-04-13 05:01:15,628	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.506 s, which may be a performance bottleneck.
# 2024-04-13 05:01:15,631	WARNING util.py:202 -- The `process_trial_result` operation took 0.509 s, which may be a performance bottleneck.
# 2024-04-13 05:01:15,632	WARNING util.py:202 -- Processing trial results took 0.510 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 05:01:15,633	WARNING util.py:202 -- The `process_trial_result` operation took 0.511 s, which may be a performance bottleneck.
# 2024-04-13 05:02:24,566	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.512 s, which may be a performance bottleneck.
# 2024-04-13 05:02:24,568	WARNING util.py:202 -- The `process_trial_result` operation took 0.515 s, which may be a performance bottleneck.
# 2024-04-13 05:02:24,569	WARNING util.py:202 -- Processing trial results took 0.516 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 05:02:24,570	WARNING util.py:202 -- The `process_trial_result` operation took 0.517 s, which may be a performance bottleneck.
# 2024-04-13 05:04:04,512	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.500 s, which may be a performance bottleneck.
# 2024-04-13 05:04:04,514	WARNING util.py:202 -- The `process_trial_result` operation took 0.503 s, which may be a performance bottleneck.
# 2024-04-13 05:04:04,516	WARNING util.py:202 -- Processing trial results took 0.505 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 05:04:04,517	WARNING util.py:202 -- The `process_trial_result` operation took 0.506 s, which may be a performance bottleneck.
# 2024-04-13 05:04:59,243	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.506 s, which may be a performance bottleneck.
# 2024-04-13 05:04:59,246	WARNING util.py:202 -- The `process_trial_result` operation took 0.510 s, which may be a performance bottleneck.
# 2024-04-13 05:04:59,248	WARNING util.py:202 -- Processing trial results took 0.512 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 05:04:59,250	WARNING util.py:202 -- The `process_trial_result` operation took 0.514 s, which may be a performance bottleneck.
# 2024-04-13 05:06:02,939	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.512 s, which may be a performance bottleneck.
# 2024-04-13 05:06:02,941	WARNING util.py:202 -- The `process_trial_result` operation took 0.514 s, which may be a performance bottleneck.
# 2024-04-13 05:06:02,942	WARNING util.py:202 -- Processing trial results took 0.515 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 05:06:02,943	WARNING util.py:202 -- The `process_trial_result` operation took 0.516 s, which may be a performance bottleneck.
# 2024-04-13 05:07:17,080	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.537 s, which may be a performance bottleneck.
# 2024-04-13 05:07:17,082	WARNING util.py:202 -- The `process_trial_result` operation took 0.539 s, which may be a performance bottleneck.
# 2024-04-13 05:07:17,083	WARNING util.py:202 -- Processing trial results took 0.540 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 05:07:17,085	WARNING util.py:202 -- The `process_trial_result` operation took 0.541 s, which may be a performance bottleneck.
# 2024-04-13 05:12:26,426	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.510 s, which may be a performance bottleneck.
# 2024-04-13 05:12:26,428	WARNING util.py:202 -- The `process_trial_result` operation took 0.512 s, which may be a performance bottleneck.
# 2024-04-13 05:12:26,429	WARNING util.py:202 -- Processing trial results took 0.513 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 05:12:26,430	WARNING util.py:202 -- The `process_trial_result` operation took 0.514 s, which may be a performance bottleneck.
# 2024-04-13 05:13:37,968	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.510 s, which may be a performance bottleneck.
# 2024-04-13 05:13:37,970	WARNING util.py:202 -- The `process_trial_result` operation took 0.512 s, which may be a performance bottleneck.
# 2024-04-13 05:13:37,972	WARNING util.py:202 -- Processing trial results took 0.514 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 05:13:37,973	WARNING util.py:202 -- The `process_trial_result` operation took 0.515 s, which may be a performance bottleneck.
# 2024-04-13 05:14:24,850	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.511 s, which may be a performance bottleneck.
# 2024-04-13 05:14:24,853	WARNING util.py:202 -- The `process_trial_result` operation took 0.514 s, which may be a performance bottleneck.
# 2024-04-13 05:14:24,855	WARNING util.py:202 -- Processing trial results took 0.516 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 05:14:24,856	WARNING util.py:202 -- The `process_trial_result` operation took 0.517 s, which may be a performance bottleneck.
# 2024-04-13 05:16:10,184	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.517 s, which may be a performance bottleneck.
# 2024-04-13 05:16:10,186	WARNING util.py:202 -- The `process_trial_result` operation took 0.519 s, which may be a performance bottleneck.
# 2024-04-13 05:16:10,187	WARNING util.py:202 -- Processing trial results took 0.520 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 05:16:10,188	WARNING util.py:202 -- The `process_trial_result` operation took 0.521 s, which may be a performance bottleneck.
# 2024-04-13 05:27:20,239	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.508 s, which may be a performance bottleneck.
# 2024-04-13 05:27:20,242	WARNING util.py:202 -- The `process_trial_result` operation took 0.511 s, which may be a performance bottleneck.
# 2024-04-13 05:27:20,243	WARNING util.py:202 -- Processing trial results took 0.512 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 05:27:20,244	WARNING util.py:202 -- The `process_trial_result` operation took 0.513 s, which may be a performance bottleneck.
# 2024-04-13 05:29:54,042	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.535 s, which may be a performance bottleneck.
# 2024-04-13 05:29:54,044	WARNING util.py:202 -- The `process_trial_result` operation took 0.537 s, which may be a performance bottleneck.
# 2024-04-13 05:29:54,046	WARNING util.py:202 -- Processing trial results took 0.539 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 05:29:54,047	WARNING util.py:202 -- The `process_trial_result` operation took 0.540 s, which may be a performance bottleneck.
# 2024-04-13 05:31:53,185	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.514 s, which may be a performance bottleneck.
# 2024-04-13 05:31:53,187	WARNING util.py:202 -- The `process_trial_result` operation took 0.516 s, which may be a performance bottleneck.
# 2024-04-13 05:31:53,188	WARNING util.py:202 -- Processing trial results took 0.517 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 05:31:53,189	WARNING util.py:202 -- The `process_trial_result` operation took 0.518 s, which may be a performance bottleneck.
# 2024-04-13 05:32:03,803	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.530 s, which may be a performance bottleneck.
# 2024-04-13 05:32:03,805	WARNING util.py:202 -- The `process_trial_result` operation took 0.532 s, which may be a performance bottleneck.
# 2024-04-13 05:32:03,806	WARNING util.py:202 -- Processing trial results took 0.533 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 05:32:03,807	WARNING util.py:202 -- The `process_trial_result` operation took 0.534 s, which may be a performance bottleneck.
# 2024-04-13 05:32:31,156	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.544 s, which may be a performance bottleneck.
# 2024-04-13 05:32:31,158	WARNING util.py:202 -- The `process_trial_result` operation took 0.547 s, which may be a performance bottleneck.
# 2024-04-13 05:32:31,159	WARNING util.py:202 -- Processing trial results took 0.548 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 05:32:31,160	WARNING util.py:202 -- The `process_trial_result` operation took 0.549 s, which may be a performance bottleneck.
# 2024-04-13 05:39:19,810	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.513 s, which may be a performance bottleneck.
# 2024-04-13 05:39:19,812	WARNING util.py:202 -- The `process_trial_result` operation took 0.515 s, which may be a performance bottleneck.
# 2024-04-13 05:39:19,814	WARNING util.py:202 -- Processing trial results took 0.517 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 05:39:19,815	WARNING util.py:202 -- The `process_trial_result` operation took 0.518 s, which may be a performance bottleneck.
# (train pid=19256)
# 2024-04-13 05:43:50,362	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.505 s, which may be a performance bottleneck.
# 2024-04-13 05:43:50,364	WARNING util.py:202 -- The `process_trial_result` operation took 0.508 s, which may be a performance bottleneck.
# 2024-04-13 05:43:50,365	WARNING util.py:202 -- Processing trial results took 0.509 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 05:43:50,366	WARNING util.py:202 -- The `process_trial_result` operation took 0.510 s, which may be a performance bottleneck.
# 2024-04-13 05:44:36,669	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.512 s, which may be a performance bottleneck.
# 2024-04-13 05:44:36,672	WARNING util.py:202 -- The `process_trial_result` operation took 0.516 s, which may be a performance bottleneck.
# 2024-04-13 05:44:36,673	WARNING util.py:202 -- Processing trial results took 0.517 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 05:44:36,674	WARNING util.py:202 -- The `process_trial_result` operation took 0.518 s, which may be a performance bottleneck.
# 2024-04-13 05:46:43,699	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.514 s, which may be a performance bottleneck.
# 2024-04-13 05:46:43,701	WARNING util.py:202 -- The `process_trial_result` operation took 0.516 s, which may be a performance bottleneck.
# 2024-04-13 05:46:43,703	WARNING util.py:202 -- Processing trial results took 0.518 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 05:46:43,704	WARNING util.py:202 -- The `process_trial_result` operation took 0.519 s, which may be a performance bottleneck.
# 2024-04-13 05:47:04,594	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.520 s, which may be a performance bottleneck.
# 2024-04-13 05:47:04,597	WARNING util.py:202 -- The `process_trial_result` operation took 0.524 s, which may be a performance bottleneck.
# 2024-04-13 05:47:04,599	WARNING util.py:202 -- Processing trial results took 0.526 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 05:47:04,600	WARNING util.py:202 -- The `process_trial_result` operation took 0.527 s, which may be a performance bottleneck.
# 2024-04-13 05:47:14,615	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.506 s, which may be a performance bottleneck.
# 2024-04-13 05:47:14,618	WARNING util.py:202 -- The `process_trial_result` operation took 0.510 s, which may be a performance bottleneck.
# 2024-04-13 05:47:14,619	WARNING util.py:202 -- Processing trial results took 0.511 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 05:47:14,620	WARNING util.py:202 -- The `process_trial_result` operation took 0.512 s, which may be a performance bottleneck.
# 2024-04-13 05:47:50,181	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.514 s, which may be a performance bottleneck.
# 2024-04-13 05:47:50,184	WARNING util.py:202 -- The `process_trial_result` operation took 0.517 s, which may be a performance bottleneck.
# 2024-04-13 05:47:50,185	WARNING util.py:202 -- Processing trial results took 0.518 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 05:47:50,187	WARNING util.py:202 -- The `process_trial_result` operation took 0.520 s, which may be a performance bottleneck.
# 2024-04-13 05:48:08,294	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.508 s, which may be a performance bottleneck.
# 2024-04-13 05:48:08,296	WARNING util.py:202 -- The `process_trial_result` operation took 0.510 s, which may be a performance bottleneck.
# 2024-04-13 05:48:08,297	WARNING util.py:202 -- Processing trial results took 0.511 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 05:48:08,299	WARNING util.py:202 -- The `process_trial_result` operation took 0.512 s, which may be a performance bottleneck.
# 2024-04-13 05:50:42,161	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.508 s, which may be a performance bottleneck.
# 2024-04-13 05:50:42,164	WARNING util.py:202 -- The `process_trial_result` operation took 0.511 s, which may be a performance bottleneck.
# 2024-04-13 05:50:42,165	WARNING util.py:202 -- Processing trial results took 0.512 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 05:50:42,166	WARNING util.py:202 -- The `process_trial_result` operation took 0.513 s, which may be a performance bottleneck.
# 2024-04-13 05:54:45,943	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.557 s, which may be a performance bottleneck.
# 2024-04-13 05:54:45,945	WARNING util.py:202 -- The `process_trial_result` operation took 0.559 s, which may be a performance bottleneck.
# 2024-04-13 05:54:45,947	WARNING util.py:202 -- Processing trial results took 0.561 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 05:54:45,949	WARNING util.py:202 -- The `process_trial_result` operation took 0.563 s, which may be a performance bottleneck.
# 2024-04-13 05:54:53,838	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.538 s, which may be a performance bottleneck.
# 2024-04-13 05:54:53,839	WARNING util.py:202 -- The `process_trial_result` operation took 0.540 s, which may be a performance bottleneck.
# 2024-04-13 05:54:53,841	WARNING util.py:202 -- Processing trial results took 0.541 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 05:54:53,842	WARNING util.py:202 -- The `process_trial_result` operation took 0.543 s, which may be a performance bottleneck.
# 2024-04-13 05:55:15,812	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.517 s, which may be a performance bottleneck.
# 2024-04-13 05:55:15,813	WARNING util.py:202 -- The `process_trial_result` operation took 0.519 s, which may be a performance bottleneck.
# 2024-04-13 05:55:15,815	WARNING util.py:202 -- Processing trial results took 0.521 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 05:55:15,816	WARNING util.py:202 -- The `process_trial_result` operation took 0.522 s, which may be a performance bottleneck.
# 2024-04-13 05:56:32,147	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.528 s, which may be a performance bottleneck.
# 2024-04-13 05:56:32,149	WARNING util.py:202 -- The `process_trial_result` operation took 0.530 s, which may be a performance bottleneck.
# 2024-04-13 05:56:32,150	WARNING util.py:202 -- Processing trial results took 0.531 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 05:56:32,152	WARNING util.py:202 -- The `process_trial_result` operation took 0.533 s, which may be a performance bottleneck.
# 2024-04-13 05:56:42,699	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.515 s, which may be a performance bottleneck.
# 2024-04-13 05:56:42,701	WARNING util.py:202 -- The `process_trial_result` operation took 0.517 s, which may be a performance bottleneck.
# 2024-04-13 05:56:42,703	WARNING util.py:202 -- Processing trial results took 0.519 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 05:56:42,704	WARNING util.py:202 -- The `process_trial_result` operation took 0.520 s, which may be a performance bottleneck.
# 2024-04-13 05:57:56,746	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.503 s, which may be a performance bottleneck.
# 2024-04-13 05:57:56,749	WARNING util.py:202 -- The `process_trial_result` operation took 0.506 s, which may be a performance bottleneck.
# 2024-04-13 05:57:56,750	WARNING util.py:202 -- Processing trial results took 0.507 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 05:57:56,751	WARNING util.py:202 -- The `process_trial_result` operation took 0.508 s, which may be a performance bottleneck.
# 2024-04-13 05:59:25,736	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.504 s, which may be a performance bottleneck.
# 2024-04-13 05:59:25,738	WARNING util.py:202 -- The `process_trial_result` operation took 0.506 s, which may be a performance bottleneck.
# 2024-04-13 05:59:25,740	WARNING util.py:202 -- Processing trial results took 0.508 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 05:59:25,741	WARNING util.py:202 -- The `process_trial_result` operation took 0.509 s, which may be a performance bottleneck.
# 2024-04-13 05:59:32,890	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.506 s, which may be a performance bottleneck.
# 2024-04-13 05:59:32,892	WARNING util.py:202 -- The `process_trial_result` operation took 0.508 s, which may be a performance bottleneck.
# 2024-04-13 05:59:32,894	WARNING util.py:202 -- Processing trial results took 0.510 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 05:59:32,895	WARNING util.py:202 -- The `process_trial_result` operation took 0.511 s, which may be a performance bottleneck.
# 2024-04-13 05:59:43,277	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.528 s, which may be a performance bottleneck.
# 2024-04-13 05:59:43,279	WARNING util.py:202 -- The `process_trial_result` operation took 0.530 s, which may be a performance bottleneck.
# 2024-04-13 05:59:43,281	WARNING util.py:202 -- Processing trial results took 0.532 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 05:59:43,282	WARNING util.py:202 -- The `process_trial_result` operation took 0.533 s, which may be a performance bottleneck.
# 2024-04-13 05:59:54,117	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.518 s, which may be a performance bottleneck.
# 2024-04-13 05:59:54,119	WARNING util.py:202 -- The `process_trial_result` operation took 0.520 s, which may be a performance bottleneck.
# 2024-04-13 05:59:54,121	WARNING util.py:202 -- Processing trial results took 0.522 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 05:59:54,121	WARNING util.py:202 -- The `process_trial_result` operation took 0.522 s, which may be a performance bottleneck.
# 2024-04-13 06:04:55,216	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.504 s, which may be a performance bottleneck.
# 2024-04-13 06:04:55,219	WARNING util.py:202 -- The `process_trial_result` operation took 0.506 s, which may be a performance bottleneck.
# 2024-04-13 06:04:55,220	WARNING util.py:202 -- Processing trial results took 0.508 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 06:04:55,221	WARNING util.py:202 -- The `process_trial_result` operation took 0.509 s, which may be a performance bottleneck.
# 2024-04-13 06:05:28,482	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.520 s, which may be a performance bottleneck.
# 2024-04-13 06:05:28,484	WARNING util.py:202 -- The `process_trial_result` operation took 0.522 s, which may be a performance bottleneck.
# 2024-04-13 06:05:28,485	WARNING util.py:202 -- Processing trial results took 0.523 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 06:05:28,486	WARNING util.py:202 -- The `process_trial_result` operation took 0.524 s, which may be a performance bottleneck.
# 2024-04-13 06:05:50,930	WARNING util.py:202 -- The `process_trial_result` operation took 0.501 s, which may be a performance bottleneck.
# ...
# 2024-04-13 08:59:49,071	WARNING util.py:202 -- The `process_trial_result` operation took 0.534 s, which may be a performance bottleneck.
# 2024-04-13 09:00:31,013	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.522 s, which may be a performance bottleneck.
# 2024-04-13 09:00:31,016	WARNING util.py:202 -- The `process_trial_result` operation took 0.525 s, which may be a performance bottleneck.
# 2024-04-13 09:00:31,017	WARNING util.py:202 -- Processing trial results took 0.526 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 09:00:31,018	WARNING util.py:202 -- The `process_trial_result` operation took 0.527 s, which may be a performance bottleneck.
# 2024-04-13 09:00:53,242	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.539 s, which may be a performance bottleneck.
# 2024-04-13 09:00:53,244	WARNING util.py:202 -- The `process_trial_result` operation took 0.542 s, which may be a performance bottleneck.
# 2024-04-13 09:00:53,245	WARNING util.py:202 -- Processing trial results took 0.543 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 09:00:53,246	WARNING util.py:202 -- The `process_trial_result` operation took 0.544 s, which may be a performance bottleneck.
# 2024-04-13 09:01:20,431	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.542 s, which may be a performance bottleneck.
# 2024-04-13 09:01:20,434	WARNING util.py:202 -- The `process_trial_result` operation took 0.545 s, which may be a performance bottleneck.
# 2024-04-13 09:01:20,435	WARNING util.py:202 -- Processing trial results took 0.546 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 09:01:20,436	WARNING util.py:202 -- The `process_trial_result` operation took 0.547 s, which may be a performance bottleneck.
# 2024-04-13 09:01:38,814	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.529 s, which may be a performance bottleneck.
# 2024-04-13 09:01:38,817	WARNING util.py:202 -- The `process_trial_result` operation took 0.532 s, which may be a performance bottleneck.
# 2024-04-13 09:01:38,818	WARNING util.py:202 -- Processing trial results took 0.533 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 09:01:38,819	WARNING util.py:202 -- The `process_trial_result` operation took 0.534 s, which may be a performance bottleneck.
# 2024-04-13 09:01:42,338	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.500 s, which may be a performance bottleneck.
# 2024-04-13 09:01:42,340	WARNING util.py:202 -- The `process_trial_result` operation took 0.502 s, which may be a performance bottleneck.
# 2024-04-13 09:01:42,342	WARNING util.py:202 -- Processing trial results took 0.504 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 09:01:42,343	WARNING util.py:202 -- The `process_trial_result` operation took 0.505 s, which may be a performance bottleneck.
# 2024-04-13 09:01:55,193	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.527 s, which may be a performance bottleneck.
# 2024-04-13 09:01:55,196	WARNING util.py:202 -- The `process_trial_result` operation took 0.530 s, which may be a performance bottleneck.
# 2024-04-13 09:01:55,197	WARNING util.py:202 -- Processing trial results took 0.531 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 09:01:55,199	WARNING util.py:202 -- The `process_trial_result` operation took 0.533 s, which may be a performance bottleneck.
# 2024-04-13 09:02:46,695	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.517 s, which may be a performance bottleneck.
# 2024-04-13 09:02:46,697	WARNING util.py:202 -- The `process_trial_result` operation took 0.519 s, which may be a performance bottleneck.
# 2024-04-13 09:02:46,699	WARNING util.py:202 -- Processing trial results took 0.521 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 09:02:46,700	WARNING util.py:202 -- The `process_trial_result` operation took 0.522 s, which may be a performance bottleneck.
# 2024-04-13 09:02:51,332	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.566 s, which may be a performance bottleneck.
# 2024-04-13 09:02:51,333	WARNING util.py:202 -- The `process_trial_result` operation took 0.567 s, which may be a performance bottleneck.
# 2024-04-13 09:02:51,334	WARNING util.py:202 -- Processing trial results took 0.568 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 09:02:51,336	WARNING util.py:202 -- The `process_trial_result` operation took 0.570 s, which may be a performance bottleneck.
# 2024-04-13 09:03:38,623	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.507 s, which may be a performance bottleneck.
# 2024-04-13 09:03:38,625	WARNING util.py:202 -- The `process_trial_result` operation took 0.509 s, which may be a performance bottleneck.
# 2024-04-13 09:03:38,627	WARNING util.py:202 -- Processing trial results took 0.511 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 09:03:38,628	WARNING util.py:202 -- The `process_trial_result` operation took 0.512 s, which may be a performance bottleneck.
# 2024-04-13 09:03:42,459	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.517 s, which may be a performance bottleneck.
# 2024-04-13 09:03:42,461	WARNING util.py:202 -- The `process_trial_result` operation took 0.520 s, which may be a performance bottleneck.
# 2024-04-13 09:03:42,463	WARNING util.py:202 -- Processing trial results took 0.522 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 09:03:42,464	WARNING util.py:202 -- The `process_trial_result` operation took 0.523 s, which may be a performance bottleneck.
# 2024-04-13 09:03:46,821	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.546 s, which may be a performance bottleneck.
# 2024-04-13 09:03:46,824	WARNING util.py:202 -- The `process_trial_result` operation took 0.550 s, which may be a performance bottleneck.
# 2024-04-13 09:03:46,825	WARNING util.py:202 -- Processing trial results took 0.551 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 09:03:46,827	WARNING util.py:202 -- The `process_trial_result` operation took 0.552 s, which may be a performance bottleneck.
# 2024-04-13 09:04:33,900	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.547 s, which may be a performance bottleneck.
# 2024-04-13 09:04:33,902	WARNING util.py:202 -- The `process_trial_result` operation took 0.549 s, which may be a performance bottleneck.
# 2024-04-13 09:04:33,904	WARNING util.py:202 -- Processing trial results took 0.551 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 09:04:33,906	WARNING util.py:202 -- The `process_trial_result` operation took 0.553 s, which may be a performance bottleneck.
# 2024-04-13 09:04:44,243	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.505 s, which may be a performance bottleneck.
# 2024-04-13 09:04:44,245	WARNING util.py:202 -- The `process_trial_result` operation took 0.507 s, which may be a performance bottleneck.
# 2024-04-13 09:04:44,246	WARNING util.py:202 -- Processing trial results took 0.508 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 09:04:44,247	WARNING util.py:202 -- The `process_trial_result` operation took 0.509 s, which may be a performance bottleneck.
# 2024-04-13 09:04:56,450	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.503 s, which may be a performance bottleneck.
# 2024-04-13 09:04:56,452	WARNING util.py:202 -- The `process_trial_result` operation took 0.505 s, which may be a performance bottleneck.
# 2024-04-13 09:04:56,454	WARNING util.py:202 -- Processing trial results took 0.507 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 09:04:56,455	WARNING util.py:202 -- The `process_trial_result` operation took 0.508 s, which may be a performance bottleneck.
# 2024-04-13 09:04:59,865	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.546 s, which may be a performance bottleneck.
# 2024-04-13 09:04:59,867	WARNING util.py:202 -- The `process_trial_result` operation took 0.548 s, which may be a performance bottleneck.
# 2024-04-13 09:04:59,868	WARNING util.py:202 -- Processing trial results took 0.549 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 09:04:59,869	WARNING util.py:202 -- The `process_trial_result` operation took 0.550 s, which may be a performance bottleneck.
# 2024-04-13 09:05:04,393	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.523 s, which may be a performance bottleneck.
# 2024-04-13 09:05:04,395	WARNING util.py:202 -- The `process_trial_result` operation took 0.525 s, which may be a performance bottleneck.
# 2024-04-13 09:05:04,397	WARNING util.py:202 -- Processing trial results took 0.527 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 09:05:04,398	WARNING util.py:202 -- The `process_trial_result` operation took 0.528 s, which may be a performance bottleneck.
# 2024-04-13 09:05:08,027	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.540 s, which may be a performance bottleneck.
# 2024-04-13 09:05:08,030	WARNING util.py:202 -- The `process_trial_result` operation took 0.543 s, which may be a performance bottleneck.
# 2024-04-13 09:05:08,031	WARNING util.py:202 -- Processing trial results took 0.544 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 09:05:08,032	WARNING util.py:202 -- The `process_trial_result` operation took 0.545 s, which may be a performance bottleneck.
# 2024-04-13 09:05:25,996	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.502 s, which may be a performance bottleneck.
# 2024-04-13 09:05:25,998	WARNING util.py:202 -- The `process_trial_result` operation took 0.504 s, which may be a performance bottleneck.
# 2024-04-13 09:05:26,000	WARNING util.py:202 -- Processing trial results took 0.506 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 09:05:26,002	WARNING util.py:202 -- The `process_trial_result` operation took 0.508 s, which may be a performance bottleneck.
# 2024-04-13 09:05:54,043	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.509 s, which may be a performance bottleneck.
# 2024-04-13 09:05:54,045	WARNING util.py:202 -- The `process_trial_result` operation took 0.511 s, which may be a performance bottleneck.
# 2024-04-13 09:05:54,047	WARNING util.py:202 -- Processing trial results took 0.512 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 09:05:54,047	WARNING util.py:202 -- The `process_trial_result` operation took 0.513 s, which may be a performance bottleneck.
# 2024-04-13 09:06:13,074	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.502 s, which may be a performance bottleneck.
# 2024-04-13 09:06:13,077	WARNING util.py:202 -- The `process_trial_result` operation took 0.506 s, which may be a performance bottleneck.
# 2024-04-13 09:06:13,078	WARNING util.py:202 -- Processing trial results took 0.507 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 09:06:13,079	WARNING util.py:202 -- The `process_trial_result` operation took 0.508 s, which may be a performance bottleneck.
# 2024-04-13 09:06:16,846	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.508 s, which may be a performance bottleneck.
# 2024-04-13 09:06:16,848	WARNING util.py:202 -- The `process_trial_result` operation took 0.511 s, which may be a performance bottleneck.
# 2024-04-13 09:06:16,850	WARNING util.py:202 -- Processing trial results took 0.512 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 09:06:16,851	WARNING util.py:202 -- The `process_trial_result` operation took 0.514 s, which may be a performance bottleneck.
# 2024-04-13 09:06:30,622	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.503 s, which may be a performance bottleneck.
# 2024-04-13 09:06:30,623	WARNING util.py:202 -- The `process_trial_result` operation took 0.505 s, which may be a performance bottleneck.
# 2024-04-13 09:06:30,625	WARNING util.py:202 -- Processing trial results took 0.507 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 09:06:30,626	WARNING util.py:202 -- The `process_trial_result` operation took 0.508 s, which may be a performance bottleneck.
# 2024-04-13 09:06:49,832	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.511 s, which may be a performance bottleneck.
# 2024-04-13 09:06:49,833	WARNING util.py:202 -- The `process_trial_result` operation took 0.513 s, which may be a performance bottleneck.
# 2024-04-13 09:06:49,835	WARNING util.py:202 -- Processing trial results took 0.515 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 09:06:49,836	WARNING util.py:202 -- The `process_trial_result` operation took 0.516 s, which may be a performance bottleneck.
# 2024-04-13 09:07:00,242	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.504 s, which may be a performance bottleneck.
# 2024-04-13 09:07:00,244	WARNING util.py:202 -- The `process_trial_result` operation took 0.507 s, which may be a performance bottleneck.
# 2024-04-13 09:07:00,246	WARNING util.py:202 -- Processing trial results took 0.509 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 09:07:00,247	WARNING util.py:202 -- The `process_trial_result` operation took 0.510 s, which may be a performance bottleneck.
# 2024-04-13 09:07:13,987	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.517 s, which may be a performance bottleneck.
# 2024-04-13 09:07:13,990	WARNING util.py:202 -- The `process_trial_result` operation took 0.520 s, which may be a performance bottleneck.
# 2024-04-13 09:07:13,992	WARNING util.py:202 -- Processing trial results took 0.521 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 09:07:13,993	WARNING util.py:202 -- The `process_trial_result` operation took 0.523 s, which may be a performance bottleneck.
# 2024-04-13 09:07:19,821	INFO timeout.py:54 -- Reached timeout of 36000 seconds. Stopping all trials.
# 2024-04-13 09:07:33,220	INFO tune.py:1016 -- Wrote the latest version of all result files and experiment state to 'C:/Users/STEIM/ray_results/GA' in 13.0880s.
# 2024-04-13 09:07:34,035	INFO tune.py:1048 -- Total run time: 36014.74 seconds (36000.81 seconds for the tuning loop).
# 2024-04-13 09:08:03,507	WARNING experiment_analysis.py:190 -- Failed to fetch metrics for 1 trial(s):
# - train_701a8d1f: FileNotFoundError('Could not fetch metrics for train_701a8d1f: both result.json and progress.csv were not found at C:/Users/STEIM/ray_results/GA/train_701a8d1f')

# %%
analysis.best_config
# Out:
# {'POP_SIZE': 500,
#  'INITIAL_MUTATION_RATE': 0.7107651734817916,
#  'FINAL_MUTATION_RATE': 0.1969285330766747,
#  'MUTATION_ELEMENTS': 116,
#  'INITIAL_EXPLORATION': 0.8975767920426596,
#  'ELITISM': 0.9088269091612435,
#  'SURVIVAL_RATE': 0.3080815859946041}

# %%
tuning_history = (
    pd.concat(analysis.trial_dataframes, axis=0)
    .reset_index(drop=True)
    .filter(
        [
            "trial_id",
            "fitness",
            "training_iteration",
            "config/POP_SIZE",
            "config/INITIAL_MUTATION_RATE",
            "config/FINAL_MUTATION_RATE",
            "config/INITIAL_EXPLORATION",
            "config/ELITISM",
            "config/SURVIVAL_RATE",
        ]
    )
)

# Only keep the top combinations
num_best = 1000
top_combinations = tuning_history.groupby("trial_id").last().reset_index().sort_values("fitness", ascending=False).head(num_best)["trial_id"].to_list()
tuning_history = tuning_history.query("trial_id in @top_combinations")

# %%
(
    tuning_history
    .to_csv(
        f"./Tuning Results/{datetime.datetime.now().strftime('%Y%m%d%H%M')}_GA_Elite_numpy.csv",
        index=False,
    )
)
