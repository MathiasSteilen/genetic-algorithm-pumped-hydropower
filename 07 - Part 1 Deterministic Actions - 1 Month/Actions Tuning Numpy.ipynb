# %% [markdown]
# # Pumped-Storage Optimisation with Genetic Algorithm and MILP

# %%
import pandas as pd
import datetime
import numpy as np
import plotnine as pn
import plotly.graph_objs as go
import plotly.express as px
from tqdm.notebook import tqdm
from IPython.display import clear_output, display
import os
from itertools import product

# Import own implementations
from milp import MILP
import genetic_numpy
from genetic_numpy import GA_discrete_actions, evaluate_fitness

# Importing tuning libraries
import ray
from ray import train, tune
from ray.tune.search.optuna import OptunaSearch
from ray.tune.schedulers import ASHAScheduler

background_colour = "#F2F2F2"
pn.theme_set(
    pn.theme_classic()
    + pn.theme(
        text=pn.element_text(family="monospace"),
        plot_background=pn.element_rect(
            fill=background_colour, colour=background_colour
        ),
        panel_background=pn.element_rect(
            fill=background_colour, colour=background_colour
        ),
        legend_background=pn.element_rect(
            fill=background_colour, colour=background_colour
        ),
    )
)

# %load_ext blackcellmagic
# Out:
# The blackcellmagic extension is already loaded. To reload it, use:
#   %reload_ext blackcellmagic

# %% [markdown]
# ## Reading the Price data

# %%
df = (
    pd.read_csv("../01 - Data/spot_prices_utc.csv")
    .assign(utc_time=lambda x: pd.to_datetime(x.utc_time))
    .query('utc_time >= @pd.Timestamp("2022-08-01 00:00", tz="UTC")')
    .head(24 * 31)
    .reset_index(drop=True)
)
df
# Out:
#        spot                  utc_time
# 0    387.62 2022-08-01 00:00:00+00:00
# 1    375.77 2022-08-01 01:00:00+00:00
# 2    372.42 2022-08-01 02:00:00+00:00
# 3    394.23 2022-08-01 03:00:00+00:00
# 4    430.72 2022-08-01 04:00:00+00:00
# ..      ...                       ...
# 739  709.92 2022-08-31 19:00:00+00:00
# 740  679.91 2022-08-31 20:00:00+00:00
# 741  639.95 2022-08-31 21:00:00+00:00
# 742  569.92 2022-08-31 22:00:00+00:00
# 743  539.91 2022-08-31 23:00:00+00:00
#
# [744 rows x 2 columns]

# %% [markdown]
# ## The Power Plant

# %%
plant_params = {
    "EFFICIENCY": 0.75,
    "MAX_STORAGE_M3": 5000,
    "MIN_STORAGE_M3": 0,
    "TURBINE_POWER_MW": 100,
    "PUMP_POWER_MW": 100,
    "TURBINE_RATE_M3H": 500,
    "MIN_STORAGE_MWH": 0,
    "INITIAL_WATER_LEVEL_PCT": 0,
}
plant_params["INITIAL_WATER_LEVEL"] = (
    plant_params["INITIAL_WATER_LEVEL_PCT"] * plant_params["MAX_STORAGE_M3"]
)
plant_params["PUMP_RATE_M3H"] = (
    plant_params["TURBINE_RATE_M3H"] * plant_params["EFFICIENCY"]
)
plant_params["MAX_STORAGE_MWH"] = (
    plant_params["MAX_STORAGE_M3"] / plant_params["TURBINE_RATE_M3H"]
) * plant_params["TURBINE_POWER_MW"]

# %% [markdown]
# ## GA

# %%
ga_solver = GA_discrete_actions(
    plant_params=plant_params, spot=df["spot"], utc_time=df["utc_time"], actions_space= [-1, 0, 1]
)

# %%
analysis = ga_solver.tune(
    tune_config={
        "POP_SIZE": 500,
        "INITIAL_MUTATION_RATE": tune.uniform(0.05, 0.75),
        "FINAL_MUTATION_RATE": tune.uniform(0.001, 0.2),
        "INITIAL_EXPLORATION": tune.uniform(0.05, 0.95),
        "ELITISM": tune.uniform(0.05, 0.95),
        "SURVIVAL_RATE": tune.uniform(0.05, 0.95),
    },
    total_generations=500,
    timeout_s=60*60*10,
)
# Out:
# 2024-04-13 21:49:20,519	INFO worker.py:1585 -- Calling ray.init() again after it has already been called.
# 2024-04-13 21:49:20,522	INFO tune.py:613 -- [output] This uses the legacy output and progress reporter, as Jupyter notebooks are not supported by the new engine, yet. For more information, please see https://github.com/ray-project/ray/issues/36949
# [I 2024-04-13 21:49:20,526] A new study created in memory with name: optuna
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-04-14 07:49:34</td></tr>
# <tr><td>Running for: </td><td>10:00:13.68        </td></tr>
# <tr><td>Memory:      </td><td>29.2/31.6 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 28.0/28 CPUs, 0/1 GPUs (0.0/1.0 accelerator_type:RTX)
#     </div>
#     <div class="vDivider"></div>
# <div class="messages">
#   <h3>Messages</h3>
#   : ***LOW MEMORY*** less than 10% of the memory on this node is available for use. This can cause unexpected crashes. Consider reducing the memory used by your application or reducing the Ray object store size by setting `object_store_memory` when calling `ray.init`.
#
#
# </div>
# <style>
# .messages {
#   color: var(--jp-ui-font-color1);
#   display: flex;
#   flex-direction: column;
#   padding-left: 1em;
#   overflow-y: auto;
# }
# .messages h3 {
#   font-weight: bold;
# }
# .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name    </th><th>status    </th><th>loc            </th><th style="text-align: right;">  ELITISM</th><th style="text-align: right;">  FINAL_MUTATION_RATE</th><th style="text-align: right;">  INITIAL_EXPLORATION</th><th style="text-align: right;">          INITIAL_MUTATION_RAT
# E</th><th style="text-align: right;">  SURVIVAL_RATE</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  fitness</th></tr>
# </thead>
# <tbody>
# <tr><td>train_7e5cb66d</td><td>TERMINATED</td><td>127.0.0.1:16616</td><td style="text-align: right;">0.790715 </td><td style="text-align: right;">           0.0617156 </td><td style="text-align: right;">            0.357557 </td><td style="text-align: right;">0.492059 </td><td style="text-align: right;">      0.880739 </td><td style="text-align: right;">   500</td><td style="text-align: right;">        44.9252 </td><td style="text-align: right;"> 459547  </td></tr>
# <tr><td>train_dd8445e4</td><td>TERMINATED</td><td>127.0.0.1:24768</td><td style="text-align: right;">0.329691 </td><td style="text-align: right;">           0.0223961 </td><td style="text-align: right;">            0.645974 </td><td style="text-align: right;">0.372315 </td><td style="text-align: right;">      0.75595  </td><td style="text-align: right;">   500</td><td style="text-align: right;">        48.8368 </td><td style="text-align: right;"> 388139  </td></tr>
# <tr><td>train_763acc5b</td><td>TERMINATED</td><td>127.0.0.1:2772 </td><td style="text-align: right;">0.857259 </td><td style="text-align: right;">           0.185122  </td><td style="text-align: right;">            0.927749 </td><td style="text-align: right;">0.0523555</td><td style="text-align: right;">      0.0519387</td><td style="text-align: right;">   500</td><td style="text-align: right;">        67.8276 </td><td style="text-align: right;"> 465003  </td></tr>
# <tr><td>train_8634e8c4</td><td>TERMINATED</td><td>127.0.0.1:23836</td><td style="text-align: right;">0.677012 </td><td style="text-align: right;">           0.161234  </td><td style="text-align: right;">            0.251382 </td><td style="text-align: right;">0.604208 </td><td style="text-align: right;">      0.121743 </td><td style="text-align: right;">   500</td><td style="text-align: right;">        69.9887 </td><td style="text-align: right;"> 519798  </td></tr>
# <tr><td>train_9b559438</td><td>TERMINATED</td><td>127.0.0.1:19056</td><td style="text-align: right;">0.218422 </td><td style="text-align: right;">           0.0458492 </td><td style="text-align: right;">            0.651761 </td><td style="text-align: right;">0.5164   </td><td style="text-align: right;">      0.625609 </td><td style="text-align: right;">   500</td><td style="text-align: right;">        57.2696 </td><td style="text-align: right;">  12476  </td></tr>
# <tr><td>train_f27395c0</td><td>TERMINATED</td><td>127.0.0.1:22068</td><td style="text-align: right;">0.355974 </td><td style="text-align: right;">           0.1497    </td><td style="text-align: right;">            0.547407 </td><td style="text-align: right;">0.552621 </td><td style="text-align: right;">      0.628198 </td><td style="text-align: right;">   500</td><td style="text-align: right;">        62.4387 </td><td style="text-align: right;"> 323085  </td></tr>
# <tr><td>train_a9f5e4e5</td><td>TERMINATED</td><td>127.0.0.1:15556</td><td style="text-align: right;">0.226848 </td><td style="text-align: right;">           0.199522  </td><td style="text-align: right;">            0.344797 </td><td style="text-align: right;">0.123853 </td><td style="text-align: right;">      0.907078 </td><td style="text-align: right;">   500</td><td style="text-align: right;">        59.0401 </td><td style="text-align: right;"> 360165  </td></tr>
# <tr><td>train_c58d5453</td><td>TERMINATED</td><td>127.0.0.1:19084</td><td style="text-align: right;">0.344983 </td><td style="text-align: right;">           0.148981  </td><td style="text-align: right;">            0.073148 </td><td style="text-align: right;">0.512358 </td><td style="text-align: right;">      0.109587 </td><td style="text-align: right;">   500</td><td style="text-align: right;">        76.1607 </td><td style="text-align: right;">      0  </td></tr>
# <tr><td>train_2639be56</td><td>TERMINATED</td><td>127.0.0.1:19420</td><td style="text-align: right;">0.94411  </td><td style="text-align: right;">           0.100772  </td><td style="text-align: right;">            0.399805 </td><td style="text-align: right;">0.717957 </td><td style="text-align: right;">      0.843084 </td><td style="text-align: right;">   500</td><td style="text-align: right;">        65.4115 </td><td style="text-align: right;"> 386369  </td></tr>
# <tr><td>train_dc9d46ec</td><td>TERMINATED</td><td>127.0.0.1:16568</td><td style="text-align: right;">0.301585 </td><td style="text-align: right;">           0.0818027 </td><td style="text-align: right;">            0.515527 </td><td style="text-align: right;">0.736412 </td><td style="text-align: right;">      0.0756012</td><td style="text-align: right;">   500</td><td style="text-align: right;">        83.7339 </td><td style="text-align: right;"> 419506  </td></tr>
# <tr><td>train_794b73af</td><td>TERMINATED</td><td>127.0.0.1:7192 </td><td style="text-align: right;">0.628942 </td><td style="text-align: right;">           0.0222422 </td><td style="text-align: right;">            0.125249 </td><td style="text-align: right;">0.38487  </td><td style="text-align: right;">      0.334074 </td><td style="text-align: right;">   500</td><td style="text-align: right;">        76.6302 </td><td style="text-align: right;"> 326335  </td></tr>
# <tr><td>train_60ac1991</td><td>TERMINATED</td><td>127.0.0.1:2512 </td><td style="text-align: right;">0.222944 </td><td style="text-align: right;">           0.0452051 </td><td style="text-align: right;">            0.926885 </td><td style="text-align: right;">0.40314  </td><td style="text-align: right;">      0.283343 </td><td style="text-align: right;">   500</td><td style="text-align: right;">        77.8322 </td><td style="text-align: right;">      0  </td></tr>
# <tr><td>train_dd7b10fd</td><td>TERMINATED</td><td>127.0.0.1:36328</td><td style="text-align: right;">0.478312 </td><td style="text-align: right;">           0.121203  </td><td style="text-align: right;">            0.0817516</td><td style="text-align: right;">0.505271 </td><td style="text-align: right;">      0.0676642</td><td style="text-align: right;">   500</td><td style="text-align: right;">        86.3677 </
# <div class="trialProgress">
#   <h3>Trial Progress</h3>
#   <table>
# <thead>
# <tr><th>Trial name    </th><th style="text-align: right;">         fitness</th></tr>
# </thead>
# <tbody>
# <tr><td>train_0001a4a4</td><td style="text-align: right;">662976          </td></tr>
# <tr><td>train_00571e72</td><td style="text-align: right;">693367          </td></tr>
# <tr><td>train_0058d8c1</td><td style="text-align: right;">659190          </td></tr>
# <tr><td>train_0068eef9</td><td style="text-align: right;">651804          </td></tr>
# <tr><td>train_0077d4d8</td><td style="text-align: right;">697595          </td></tr>
# <tr><td>train_0077eaaf</td><td style="text-align: right;">648993          </td></tr>
# <tr><td>train_007baa38</td><td style="text-align: right;">471593          </td></tr>
# <tr><td>train_00880083</td><td style="text-align: right;">634584          </td></tr>
# <tr><td>train_00c8f82a</td><td style="text-align: right;">635668          </td></tr>
# <tr><td>train_00d76c27</td><td style="text-align: right;">  5596          </td></tr>
# <tr><td>train_00e9bbfb</td><td style="text-align: right;">684347          </td></tr>
# <tr><td>train_01094ab7</td><td style="text-align: right;">681541          </td></tr>
# <tr><td>train_012672aa</td><td style="text-align: right;">634179          </td></tr>
# <tr><td>train_013b82f2</td><td style="text-align: right;">637882          </td></tr>
# <tr><td>train_0146d141</td><td style="text-align: right;">658162          </td></tr>
# <tr><td>train_01568e73</td><td style="text-align: right;">692205          </td></tr>
# <tr><td>train_01602d3e</td><td style="text-align: right;">674668          </td></tr>
# <tr><td>train_016568e6</td><td style="text-align: right;">694325          </td></tr>
# <tr><td>train_01709e43</td><td style="text-align: right;">674718          </td></tr>
# <tr><td>train_01849808</td><td style="text-align: right;">648726          </td></tr>
# <tr><td>train_0197af25</td><td style="text-align: right;">685808          </td></tr>
# <tr><td>train_019ca90c</td><td style="text-align: right;">504951          </td></tr>
# <tr><td>train_01b0ecd9</td><td style="text-align: right;">646044          </td></tr>
# <tr><td>train_01c58704</td><td style="text-align: right;">636877          </td></tr>
# <tr><td>train_01d123df</td><td style="text-align: right;">708582          </td></tr>
# <tr><td>train_01d7cc28</td><td style="text-align: right;">556238          </td></tr>
# <tr><td>train_01e4fda3</td><td style="text-align: right;">606155          </td></tr>
# <tr><td>train_01f49185</td><td style="text-align: right;">633139          </td></tr>
# <tr><td>train_022505fe</td><td style="text-align: right;">637654          </td></tr>
# <tr><td>train_023e2af2</td><td style="text-align: right;">634973          </td></tr>
# <tr><td>train_0243d7ff</td><td style="text-align: right;">596358          </td></tr>
# <tr><td>train_026f3f46</td><td style="text-align: right;">534498          </td></tr>
# <tr><td>train_028363d7</td><td style="text-align: right;">678866          </td></tr>
# <tr><td>train_02a72abf</td><td style="text-align: right;">699378          </td></tr>
# <tr><td>train_02a8bdca</td><td style="text-align: right;">646922          </td></tr>
# <tr><td>train_02b1d191</td><td style="text-align: right;">468879          </td></tr>
# <tr><td>train_02b543d5</td><td style="text-align: right;">683036          </td></tr>
# <tr><td>train_02c969f7</td><td style="text-align: right;">680362          </td></tr>
# <tr><td>train_02e733d4</td><td style="text-align: right;">647713          </td></tr>
# <tr><td>train_02f16e77</td><td style="text-align: right;">658303          </td></tr>
# <tr><td>train_02f332e9</td><td style="text-align: right;">410607          </td></tr>
# <tr><td>train_02f50dec</td><td style="text-align: right;">633502          </td></tr>
# <tr><td>train_02f7accf</td><td style="text-align: right;">695714          </td></tr>
# <tr><td>train_03088ca7</td><td style="text-align: right;">577640          </td></tr>
# <tr><td>train_0313c018</td><td style="text-align: right;">576156          </td></tr>
# <tr><td>train_0333bf5d</td><td style="text-align: right;">584822          </td></tr>
# <tr><td>train_033b0583</td><td style="text-align: right;">626012          </td></tr>
# <tr><td>train_034003c6</td><td style="text-align: right;">686161          </td></tr>
# <tr><td>train_0376fd9a</td><td style="text-align: right;">566221          </td></tr>
# <tr><td>train_03991074</td><td style="text-align: right;">708842          </td></tr>
# <tr><td>train_03a81e13</td><td style="text-align: right;">456477          </td></tr>
# <tr><td>train_03bc2f8e</td><td style="text-align: right;">685113          </td></tr>
# <tr><td>train_03e699ba</td><td style="text-align: right;">665608          </td></tr>
# <tr><td>train_03f25051</td><td style="text-align: right;">440542          </td></tr>
# <tr><td>train_04083668</td><td style="text-align: right;">619490          </td></tr>
# <tr><td>train_04163087</td><td style="text-align: right;">670788          </td></tr>
# <tr><td>train_04560d4a</td><td style="text-align: right;">602951          </td></tr>
# <tr><td>train_04745a52</td><td style="text-align: right;">698625          </td></tr>
# <tr><td>train_048b81b9</td><td style="text-align: right;">699800          </td></tr>
# <tr><td>train_04b9588d</td><td style="text-align: right;">550338          </td></tr>
# <tr><td>train_04d0d43f</td><td style="text-align: right;">674360          </td></tr>
# <tr><td>train_04d430a5</td><td style="text-align: right;">625707          </td></tr>
# <tr><td>train_04ddc4f5</td><td style="text-align: right;">660577          </td></tr>
# <tr><td>train_04fd07d2</td><td style="text-align: right;">673425          </td></tr>
# <tr><td>train_05269134</td><td style="text-align: right;">682713          </td></tr>
# <tr><td>train_0526f7ae</td><td style="text-align: right;">684497          </td></tr>
# <tr><td>train_0537448b</td><td style="text-align: right;">711612          </td></tr>
# <tr><td>train_0570ff04</td><td style="text-align: right;">710071          </td></tr>
# <tr><td>train_0573a01a</td><td style="text-align: right;">679537          </td></tr>
# <tr><td>train_05a4c845</td><td style="text-align: right;">692979          </td></tr>
# <tr><td>train_05c47714</td><td style="text-align: right;">661278          </td></tr>
# <tr><td>train_05ccaf5b</td><td style="text-align: right;">689598          </td></tr>
# <tr><td>train_05cdc233</td><td style="text-align: right;">672346          </td></tr>
# <tr><td>train_05d42d00</td><td style="text-align: right;">385076          </td></tr>
# <tr><td>train_05f8b0b0</td><td style="text-align: right;">615786          </td></tr>
# <tr><td>train_05ffe107</td><td style="text-align: right;">587534          </td></tr>
# <tr><td>train_0641bbec</td><td style="text-align: right;">687749          </td></tr>
# <tr><td>train_064436ba</td><td style="text-align: right;">653411          </td></tr>
# <tr><td>train_064f00cd</td><td style="text-align: right;">496061          </td></tr>
# <tr><td>train_066a521d</td><td style="text-align: right;">651456          </td></tr>
# <tr><td>train_067b3601</td><td style="text-align: right;">696872          </td></tr>
# <tr><td>train_067ba58e</td><td style="text-align: right;">626790          </td></tr>
# <tr><td>train_067d1292</td><td style="text-align: right;">635685          </td></tr>
# <tr><td>train_06a0e14e</td><td style="text-align: right;">568641          </td></tr>
# <tr><td>train_06aa4186</td><td style="text-align: right;">678186          </td></tr>
# <tr><td>train_06c53e13</td><td style="text-align: right;">680247          </td></tr>
# <tr><td>train_06f7eec2</td><td style="text-align: right;">660833          </td></tr>
# <tr><td>train_06fa133a</td><td style="text-align: right;">593422          </td></tr>
# <tr><td>train_0701f6a9</td><td style="text-align: right;">645737          </td></tr>
# <tr><td>train_0718e760</td><td style="text-align: right;">628767          </td></tr>
# <tr><td>train_073923b6</td><td style="text-align: right;">655850          </td></tr>
# <tr><td>train_0746239e</td><td style="text-align: right;">525693          </td></tr>
# <tr><t
# 2024-04-13 21:50:03,894	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 1.052 s, which may be a performance bottleneck.
# 2024-04-13 21:50:03,897	WARNING util.py:202 -- The `process_trial_result` operation took 1.055 s, which may be a performance bottleneck.
# 2024-04-13 21:50:03,899	WARNING util.py:202 -- Processing trial results took 1.057 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 21:50:03,900	WARNING util.py:202 -- The `process_trial_result` operation took 1.058 s, which may be a performance bottleneck.
# 2024-04-13 21:50:32,813	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 2.435 s, which may be a performance bottleneck.
# 2024-04-13 21:50:32,815	WARNING util.py:202 -- The `process_trial_result` operation took 2.437 s, which may be a performance bottleneck.
# 2024-04-13 21:50:32,815	WARNING util.py:202 -- Processing trial results took 2.437 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-13 21:50:32,816	WARNING util.py:202 -- The `process_trial_result` operation took 2.438 s, which may be a performance bottleneck.
# 2024-04-14 02:47:49,303	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.502 s, which may be a performance bottleneck.
# 2024-04-14 02:47:49,305	WARNING util.py:202 -- The `process_trial_result` operation took 0.505 s, which may be a performance bottleneck.
# 2024-04-14 02:47:49,307	WARNING util.py:202 -- Processing trial results took 0.507 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 02:47:49,308	WARNING util.py:202 -- The `process_trial_result` operation took 0.508 s, which may be a performance bottleneck.
# 2024-04-14 03:03:51,994	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.512 s, which may be a performance bottleneck.
# 2024-04-14 03:03:51,996	WARNING util.py:202 -- The `process_trial_result` operation took 0.514 s, which may be a performance bottleneck.
# 2024-04-14 03:03:51,997	WARNING util.py:202 -- Processing trial results took 0.515 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 03:03:51,998	WARNING util.py:202 -- The `process_trial_result` operation took 0.516 s, which may be a performance bottleneck.
# 2024-04-14 03:15:35,498	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.529 s, which may be a performance bottleneck.
# 2024-04-14 03:15:35,500	WARNING util.py:202 -- The `process_trial_result` operation took 0.531 s, which may be a performance bottleneck.
# 2024-04-14 03:15:35,501	WARNING util.py:202 -- Processing trial results took 0.532 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 03:15:35,502	WARNING util.py:202 -- The `process_trial_result` operation took 0.533 s, which may be a performance bottleneck.
# 2024-04-14 03:23:20,285	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.507 s, which may be a performance bottleneck.
# 2024-04-14 03:23:20,288	WARNING util.py:202 -- The `process_trial_result` operation took 0.510 s, which may be a performance bottleneck.
# 2024-04-14 03:23:20,289	WARNING util.py:202 -- Processing trial results took 0.511 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 03:23:20,291	WARNING util.py:202 -- The `process_trial_result` operation took 0.513 s, which may be a performance bottleneck.
# 2024-04-14 03:33:06,623	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.521 s, which may be a performance bottleneck.
# 2024-04-14 03:33:06,626	WARNING util.py:202 -- The `process_trial_result` operation took 0.524 s, which may be a performance bottleneck.
# 2024-04-14 03:33:06,627	WARNING util.py:202 -- Processing trial results took 0.525 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 03:33:06,628	WARNING util.py:202 -- The `process_trial_result` operation took 0.525 s, which may be a performance bottleneck.
# 2024-04-14 03:36:25,705	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.540 s, which may be a performance bottleneck.
# 2024-04-14 03:36:25,707	WARNING util.py:202 -- The `process_trial_result` operation took 0.542 s, which may be a performance bottleneck.
# 2024-04-14 03:36:25,708	WARNING util.py:202 -- Processing trial results took 0.543 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 03:36:25,709	WARNING util.py:202 -- The `process_trial_result` operation took 0.544 s, which may be a performance bottleneck.
# 2024-04-14 03:48:42,211	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.566 s, which may be a performance bottleneck.
# 2024-04-14 03:48:42,213	WARNING util.py:202 -- The `process_trial_result` operation took 0.567 s, which may be a performance bottleneck.
# 2024-04-14 03:48:42,214	WARNING util.py:202 -- Processing trial results took 0.569 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 03:48:42,215	WARNING util.py:202 -- The `process_trial_result` operation took 0.570 s, which may be a performance bottleneck.
# 2024-04-14 03:50:55,412	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.548 s, which may be a performance bottleneck.
# 2024-04-14 03:50:55,413	WARNING util.py:202 -- The `process_trial_result` operation took 0.549 s, which may be a performance bottleneck.
# 2024-04-14 03:50:55,415	WARNING util.py:202 -- Processing trial results took 0.551 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 03:50:55,416	WARNING util.py:202 -- The `process_trial_result` operation took 0.553 s, which may be a performance bottleneck.
# 2024-04-14 03:52:50,797	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.535 s, which may be a performance bottleneck.
# 2024-04-14 03:52:50,799	WARNING util.py:202 -- The `process_trial_result` operation took 0.537 s, which may be a performance bottleneck.
# 2024-04-14 03:52:50,801	WARNING util.py:202 -- Processing trial results took 0.539 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 03:52:50,802	WARNING util.py:202 -- The `process_trial_result` operation took 0.540 s, which may be a performance bottleneck.
# 2024-04-14 03:54:04,034	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.516 s, which may be a performance bottleneck.
# 2024-04-14 03:54:04,035	WARNING util.py:202 -- The `process_trial_result` operation took 0.517 s, which may be a performance bottleneck.
# 2024-04-14 03:54:04,037	WARNING util.py:202 -- Processing trial results took 0.519 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 03:54:04,038	WARNING util.py:202 -- The `process_trial_result` operation took 0.520 s, which may be a performance bottleneck.
# 2024-04-14 03:57:21,244	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 2.037 s, which may be a performance bottleneck.
# 2024-04-14 03:57:21,245	WARNING util.py:202 -- The `process_trial_result` operation took 2.038 s, which may be a performance bottleneck.
# 2024-04-14 03:57:21,246	WARNING util.py:202 -- Processing trial results took 2.039 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 03:57:21,247	WARNING util.py:202 -- The `process_trial_result` operation took 2.040 s, which may be a performance bottleneck.
# 2024-04-14 04:03:20,888	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.528 s, which may be a performance bottleneck.
# 2024-04-14 04:03:20,890	WARNING util.py:202 -- The `process_trial_result` operation took 0.530 s, which may be a performance bottleneck.
# 2024-04-14 04:03:20,891	WARNING util.py:202 -- Processing trial results took 0.531 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 04:03:20,892	WARNING util.py:202 -- The `process_trial_result` operation took 0.532 s, which may be a performance bottleneck.
# 2024-04-14 04:09:54,673	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.500 s, which may be a performance bottleneck.
# 2024-04-14 04:09:54,675	WARNING util.py:202 -- The `process_trial_result` operation took 0.502 s, which may be a performance bottleneck.
# 2024-04-14 04:09:54,677	WARNING util.py:202 -- Processing trial results took 0.504 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 04:09:54,678	WARNING util.py:202 -- The `process_trial_result` operation took 0.505 s, which may be a performance bottleneck.
# 2024-04-14 04:11:04,511	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.510 s, which may be a performance bottleneck.
# 2024-04-14 04:11:04,513	WARNING util.py:202 -- The `process_trial_result` operation took 0.513 s, which may be a performance bottleneck.
# 2024-04-14 04:11:04,514	WARNING util.py:202 -- Processing trial results took 0.514 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 04:11:04,515	WARNING util.py:202 -- The `process_trial_result` operation took 0.515 s, which may be a performance bottleneck.
# 2024-04-14 04:24:01,413	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.518 s, which may be a performance bottleneck.
# 2024-04-14 04:24:01,415	WARNING util.py:202 -- The `process_trial_result` operation took 0.520 s, which may be a performance bottleneck.
# 2024-04-14 04:24:01,417	WARNING util.py:202 -- Processing trial results took 0.522 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 04:24:01,417	WARNING util.py:202 -- The `process_trial_result` operation took 0.522 s, which may be a performance bottleneck.
# 2024-04-14 04:31:54,454	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.530 s, which may be a performance bottleneck.
# 2024-04-14 04:31:54,456	WARNING util.py:202 -- The `process_trial_result` operation took 0.532 s, which may be a performance bottleneck.
# 2024-04-14 04:31:54,458	WARNING util.py:202 -- Processing trial results took 0.534 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 04:31:54,459	WARNING util.py:202 -- The `process_trial_result` operation took 0.535 s, which may be a performance bottleneck.
# 2024-04-14 04:37:08,369	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.506 s, which may be a performance bottleneck.
# 2024-04-14 04:37:08,371	WARNING util.py:202 -- The `process_trial_result` operation took 0.508 s, which may be a performance bottleneck.
# 2024-04-14 04:37:08,372	WARNING util.py:202 -- Processing trial results took 0.509 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 04:37:08,374	WARNING util.py:202 -- The `process_trial_result` operation took 0.511 s, which may be a performance bottleneck.
# 2024-04-14 04:40:19,062	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.570 s, which may be a performance bottleneck.
# 2024-04-14 04:40:19,065	WARNING util.py:202 -- The `process_trial_result` operation took 0.574 s, which may be a performance bottleneck.
# 2024-04-14 04:40:19,066	WARNING util.py:202 -- Processing trial results took 0.575 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 04:40:19,066	WARNING util.py:202 -- The `process_trial_result` operation took 0.575 s, which may be a performance bottleneck.
# 2024-04-14 04:44:02,716	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.505 s, which may be a performance bottleneck.
# 2024-04-14 04:44:02,718	WARNING util.py:202 -- The `process_trial_result` operation took 0.508 s, which may be a performance bottleneck.
# 2024-04-14 04:44:02,719	WARNING util.py:202 -- Processing trial results took 0.509 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 04:44:02,721	WARNING util.py:202 -- The `process_trial_result` operation took 0.511 s, which may be a performance bottleneck.
# 2024-04-14 04:44:51,415	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.569 s, which may be a performance bottleneck.
# 2024-04-14 04:44:51,417	WARNING util.py:202 -- The `process_trial_result` operation took 0.571 s, which may be a performance bottleneck.
# 2024-04-14 04:44:51,419	WARNING util.py:202 -- Processing trial results took 0.573 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 04:44:51,420	WARNING util.py:202 -- The `process_trial_result` operation took 0.574 s, which may be a performance bottleneck.
# 2024-04-14 04:48:55,890	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.522 s, which may be a performance bottleneck.
# 2024-04-14 04:48:55,892	WARNING util.py:202 -- The `process_trial_result` operation took 0.525 s, which may be a performance bottleneck.
# 2024-04-14 04:48:55,893	WARNING util.py:202 -- Processing trial results took 0.526 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 04:48:55,894	WARNING util.py:202 -- The `process_trial_result` operation took 0.527 s, which may be a performance bottleneck.
# 2024-04-14 04:49:02,702	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.561 s, which may be a performance bottleneck.
# 2024-04-14 04:49:02,705	WARNING util.py:202 -- The `process_trial_result` operation took 0.564 s, which may be a performance bottleneck.
# 2024-04-14 04:49:02,706	WARNING util.py:202 -- Processing trial results took 0.565 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 04:49:02,708	WARNING util.py:202 -- The `process_trial_result` operation took 0.567 s, which may be a performance bottleneck.
# 2024-04-14 04:50:58,376	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.552 s, which may be a performance bottleneck.
# 2024-04-14 04:50:58,378	WARNING util.py:202 -- The `process_trial_result` operation took 0.554 s, which may be a performance bottleneck.
# 2024-04-14 04:50:58,380	WARNING util.py:202 -- Processing trial results took 0.556 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 04:50:58,381	WARNING util.py:202 -- The `process_trial_result` operation took 0.557 s, which may be a performance bottleneck.
# 2024-04-14 04:52:00,954	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.513 s, which may be a performance bottleneck.
# 2024-04-14 04:52:00,956	WARNING util.py:202 -- The `process_trial_result` operation took 0.515 s, which may be a performance bottleneck.
# 2024-04-14 04:52:00,957	WARNING util.py:202 -- Processing trial results took 0.516 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 04:52:00,959	WARNING util.py:202 -- The `process_trial_result` operation took 0.518 s, which may be a performance bottleneck.
# 2024-04-14 05:08:21,796	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.534 s, which may be a performance bottleneck.
# 2024-04-14 05:08:21,798	WARNING util.py:202 -- The `process_trial_result` operation took 0.536 s, which may be a performance bottleneck.
# 2024-04-14 05:08:21,800	WARNING util.py:202 -- Processing trial results took 0.538 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 05:08:21,801	WARNING util.py:202 -- The `process_trial_result` operation took 0.540 s, which may be a performance bottleneck.
# 2024-04-14 05:09:04,244	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.506 s, which may be a performance bottleneck.
# 2024-04-14 05:09:04,245	WARNING util.py:202 -- The `process_trial_result` operation took 0.507 s, which may be a performance bottleneck.
# 2024-04-14 05:09:04,247	WARNING util.py:202 -- Processing trial results took 0.509 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 05:09:04,249	WARNING util.py:202 -- The `process_trial_result` operation took 0.511 s, which may be a performance bottleneck.
# 2024-04-14 05:14:01,534	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.529 s, which may be a performance bottleneck.
# 2024-04-14 05:14:01,535	WARNING util.py:202 -- The `process_trial_result` operation took 0.531 s, which may be a performance bottleneck.
# 2024-04-14 05:14:01,536	WARNING util.py:202 -- Processing trial results took 0.532 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 05:14:01,537	WARNING util.py:202 -- The `process_trial_result` operation took 0.533 s, which may be a performance bottleneck.
# 2024-04-14 05:18:08,671	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.519 s, which may be a performance bottleneck.
# 2024-04-14 05:18:08,672	WARNING util.py:202 -- The `process_trial_result` operation took 0.520 s, which may be a performance bottleneck.
# 2024-04-14 05:18:08,673	WARNING util.py:202 -- Processing trial results took 0.521 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 05:18:08,675	WARNING util.py:202 -- The `process_trial_result` operation took 0.523 s, which may be a performance bottleneck.
# 2024-04-14 05:18:42,272	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.523 s, which may be a performance bottleneck.
# 2024-04-14 05:18:42,275	WARNING util.py:202 -- The `process_trial_result` operation took 0.526 s, which may be a performance bottleneck.
# 2024-04-14 05:18:42,276	WARNING util.py:202 -- Processing trial results took 0.527 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 05:18:42,276	WARNING util.py:202 -- The `process_trial_result` operation took 0.527 s, which may be a performance bottleneck.
# 2024-04-14 05:21:00,950	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.511 s, which may be a performance bottleneck.
# 2024-04-14 05:21:00,953	WARNING util.py:202 -- The `process_trial_result` operation took 0.514 s, which may be a performance bottleneck.
# 2024-04-14 05:21:00,955	WARNING util.py:202 -- Processing trial results took 0.516 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 05:21:00,956	WARNING util.py:202 -- The `process_trial_result` operation took 0.517 s, which may be a performance bottleneck.
# 2024-04-14 05:21:18,885	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.566 s, which may be a performance bottleneck.
# 2024-04-14 05:21:18,888	WARNING util.py:202 -- The `process_trial_result` operation took 0.569 s, which may be a performance bottleneck.
# 2024-04-14 05:21:18,889	WARNING util.py:202 -- Processing trial results took 0.570 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 05:21:18,890	WARNING util.py:202 -- The `process_trial_result` operation took 0.571 s, which may be a performance bottleneck.
# 2024-04-14 05:22:31,147	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.501 s, which may be a performance bottleneck.
# 2024-04-14 05:22:31,149	WARNING util.py:202 -- The `process_trial_result` operation took 0.503 s, which may be a performance bottleneck.
# 2024-04-14 05:22:31,151	WARNING util.py:202 -- Processing trial results took 0.505 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 05:22:31,152	WARNING util.py:202 -- The `process_trial_result` operation took 0.506 s, which may be a performance bottleneck.
# 2024-04-14 05:25:29,401	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.512 s, which may be a performance bottleneck.
# 2024-04-14 05:25:29,402	WARNING util.py:202 -- The `process_trial_result` operation took 0.515 s, which may be a performance bottleneck.
# 2024-04-14 05:25:29,403	WARNING util.py:202 -- Processing trial results took 0.516 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 05:25:29,404	WARNING util.py:202 -- The `process_trial_result` operation took 0.517 s, which may be a performance bottleneck.
# 2024-04-14 05:30:06,383	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.503 s, which may be a performance bottleneck.
# 2024-04-14 05:30:06,386	WARNING util.py:202 -- The `process_trial_result` operation took 0.506 s, which may be a performance bottleneck.
# 2024-04-14 05:30:06,388	WARNING util.py:202 -- Processing trial results took 0.508 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 05:30:06,389	WARNING util.py:202 -- The `process_trial_result` operation took 0.509 s, which may be a performance bottleneck.
# 2024-04-14 05:30:13,828	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.512 s, which may be a performance bottleneck.
# 2024-04-14 05:30:13,830	WARNING util.py:202 -- The `process_trial_result` operation took 0.514 s, which may be a performance bottleneck.
# 2024-04-14 05:30:13,832	WARNING util.py:202 -- Processing trial results took 0.516 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 05:30:13,833	WARNING util.py:202 -- The `process_trial_result` operation took 0.517 s, which may be a performance bottleneck.
# 2024-04-14 05:33:00,428	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.508 s, which may be a performance bottleneck.
# 2024-04-14 05:33:00,430	WARNING util.py:202 -- The `process_trial_result` operation took 0.510 s, which may be a performance bottleneck.
# 2024-04-14 05:33:00,432	WARNING util.py:202 -- Processing trial results took 0.511 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 05:33:00,432	WARNING util.py:202 -- The `process_trial_result` operation took 0.512 s, which may be a performance bottleneck.
# 2024-04-14 05:35:07,870	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.536 s, which may be a performance bottleneck.
# 2024-04-14 05:35:07,871	WARNING util.py:202 -- The `process_trial_result` operation took 0.537 s, which may be a performance bottleneck.
# 2024-04-14 05:35:07,873	WARNING util.py:202 -- Processing trial results took 0.539 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 05:35:07,874	WARNING util.py:202 -- The `process_trial_result` operation took 0.540 s, which may be a performance bottleneck.
# 2024-04-14 05:40:32,607	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.557 s, which may be a performance bottleneck.
# 2024-04-14 05:40:32,610	WARNING util.py:202 -- The `process_trial_result` operation took 0.560 s, which may be a performance bottleneck.
# 2024-04-14 05:40:32,611	WARNING util.py:202 -- Processing trial results took 0.561 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 05:40:32,612	WARNING util.py:202 -- The `process_trial_result` operation took 0.562 s, which may be a performance bottleneck.
# 2024-04-14 05:40:54,509	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.506 s, which may be a performance bottleneck.
# 2024-04-14 05:40:54,511	WARNING util.py:202 -- The `process_trial_result` operation took 0.508 s, which may be a performance bottleneck.
# 2024-04-14 05:40:54,512	WARNING util.py:202 -- Processing trial results took 0.509 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 05:40:54,513	WARNING util.py:202 -- The `process_trial_result` operation took 0.510 s, which may be a performance bottleneck.
# 2024-04-14 05:47:15,776	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.512 s, which may be a performance bottleneck.
# 2024-04-14 05:47:15,779	WARNING util.py:202 -- The `process_trial_result` operation took 0.515 s, which may be a performance bottleneck.
# 2024-04-14 05:47:15,780	WARNING util.py:202 -- Processing trial results took 0.516 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 05:47:15,781	WARNING util.py:202 -- The `process_trial_result` operation took 0.517 s, which may be a performance bottleneck.
# 2024-04-14 05:49:27,651	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.537 s, which may be a performance bottleneck.
# 2024-04-14 05:49:27,654	WARNING util.py:202 -- The `process_trial_result` operation took 0.540 s, which may be a performance bottleneck.
# 2024-04-14 05:49:27,655	WARNING util.py:202 -- Processing trial results took 0.541 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 05:49:27,656	WARNING util.py:202 -- The `process_trial_result` operation took 0.542 s, which may be a performance bottleneck.
# 2024-04-14 05:50:20,820	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.533 s, which may be a performance bottleneck.
# 2024-04-14 05:50:20,821	WARNING util.py:202 -- The `process_trial_result` operation took 0.534 s, which may be a performance bottleneck.
# 2024-04-14 05:50:20,822	WARNING util.py:202 -- Processing trial results took 0.535 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 05:50:20,823	WARNING util.py:202 -- The `process_trial_result` operation took 0.536 s, which may be a performance bottleneck.
# 2024-04-14 05:52:29,924	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.528 s, which may be a performance bottleneck.
# 2024-04-14 05:52:29,927	WARNING util.py:202 -- The `process_trial_result` operation took 0.531 s, which may be a performance bottleneck.
# 2024-04-14 05:52:29,928	WARNING util.py:202 -- Processing trial results took 0.532 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 05:52:29,929	WARNING util.py:202 -- The `process_trial_result` operation took 0.533 s, which may be a performance bottleneck.
# 2024-04-14 06:00:13,331	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.502 s, which may be a performance bottleneck.
# 2024-04-14 06:00:13,333	WARNING util.py:202 -- The `process_trial_result` operation took 0.505 s, which may be a performance bottleneck.
# 2024-04-14 06:00:13,335	WARNING util.py:202 -- Processing trial results took 0.507 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 06:00:13,336	WARNING util.py:202 -- The `process_trial_result` operation took 0.508 s, which may be a performance bottleneck.
# 2024-04-14 06:00:28,862	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.501 s, which may be a performance bottleneck.
# 2024-04-14 06:00:28,863	WARNING util.py:202 -- The `process_trial_result` operation took 0.502 s, which may be a performance bottleneck.
# 2024-04-14 06:00:28,865	WARNING util.py:202 -- Processing trial results took 0.504 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 06:00:28,866	WARNING util.py:202 -- The `process_trial_result` operation took 0.505 s, which may be a performance bottleneck.
# 2024-04-14 06:00:33,035	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.501 s, which may be a performance bottleneck.
# 2024-04-14 06:00:33,037	WARNING util.py:202 -- The `process_trial_result` operation took 0.503 s, which may be a performance bottleneck.
# 2024-04-14 06:00:33,040	WARNING util.py:202 -- Processing trial results took 0.505 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 06:00:33,041	WARNING util.py:202 -- The `process_trial_result` operation took 0.507 s, which may be a performance bottleneck.
# 2024-04-14 06:00:55,074	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.584 s, which may be a performance bottleneck.
# 2024-04-14 06:00:55,076	WARNING util.py:202 -- The `process_trial_result` operation took 0.586 s, which may be a performance bottleneck.
# 2024-04-14 06:00:55,077	WARNING util.py:202 -- Processing trial results took 0.586 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 06:00:55,077	WARNING util.py:202 -- The `process_trial_result` operation took 0.587 s, which may be a performance bottleneck.
# 2024-04-14 06:01:46,224	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.516 s, which may be a performance bottleneck.
# 2024-04-14 06:01:46,226	WARNING util.py:202 -- The `process_trial_result` operation took 0.519 s, which may be a performance bottleneck.
# 2024-04-14 06:01:46,227	WARNING util.py:202 -- Processing trial results took 0.520 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 06:01:46,229	WARNING util.py:202 -- The `process_trial_result` operation took 0.522 s, which may be a performance bottleneck.
# 2024-04-14 06:01:57,474	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.515 s, which may be a performance bottleneck.
# 2024-04-14 06:01:57,476	WARNING util.py:202 -- The `process_trial_result` operation took 0.517 s, which may be a performance bottleneck.
# 2024-04-14 06:01:57,477	WARNING util.py:202 -- Processing trial results took 0.518 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 06:01:57,478	WARNING util.py:202 -- The `process_trial_result` operation took 0.520 s, which may be a performance bottleneck.
# 2024-04-14 06:03:39,092	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.527 s, which may be a performance bottleneck.
# 2024-04-14 06:03:39,093	WARNING util.py:202 -- The `process_trial_result` operation took 0.530 s, which may be a performance bottleneck.
# 2024-04-14 06:03:39,095	WARNING util.py:202 -- Processing trial results took 0.532 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 06:03:39,096	WARNING util.py:202 -- The `process_trial_result` operation took 0.533 s, which may be a performance bottleneck.
# 2024-04-14 06:05:38,189	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.511 s, which may be a performance bottleneck.
# ...
# 2024-04-14 07:22:45,448	WARNING util.py:202 -- The `process_trial_result` operation took 0.523 s, which may be a performance bottleneck.
# 2024-04-14 07:22:49,370	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.518 s, which may be a performance bottleneck.
# 2024-04-14 07:22:49,372	WARNING util.py:202 -- The `process_trial_result` operation took 0.521 s, which may be a performance bottleneck.
# 2024-04-14 07:22:49,374	WARNING util.py:202 -- Processing trial results took 0.523 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 07:22:49,375	WARNING util.py:202 -- The `process_trial_result` operation took 0.524 s, which may be a performance bottleneck.
# 2024-04-14 07:25:17,502	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.560 s, which may be a performance bottleneck.
# 2024-04-14 07:25:17,504	WARNING util.py:202 -- The `process_trial_result` operation took 0.562 s, which may be a performance bottleneck.
# 2024-04-14 07:25:17,506	WARNING util.py:202 -- Processing trial results took 0.564 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 07:25:17,507	WARNING util.py:202 -- The `process_trial_result` operation took 0.565 s, which may be a performance bottleneck.
# 2024-04-14 07:25:25,467	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.550 s, which may be a performance bottleneck.
# 2024-04-14 07:25:25,469	WARNING util.py:202 -- The `process_trial_result` operation took 0.552 s, which may be a performance bottleneck.
# 2024-04-14 07:25:25,470	WARNING util.py:202 -- Processing trial results took 0.553 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 07:25:25,472	WARNING util.py:202 -- The `process_trial_result` operation took 0.555 s, which may be a performance bottleneck.
# 2024-04-14 07:26:42,631	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.502 s, which may be a performance bottleneck.
# 2024-04-14 07:26:42,633	WARNING util.py:202 -- The `process_trial_result` operation took 0.504 s, which may be a performance bottleneck.
# 2024-04-14 07:26:42,635	WARNING util.py:202 -- Processing trial results took 0.506 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 07:26:42,636	WARNING util.py:202 -- The `process_trial_result` operation took 0.507 s, which may be a performance bottleneck.
# 2024-04-14 07:26:54,086	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.517 s, which may be a performance bottleneck.
# 2024-04-14 07:26:54,087	WARNING util.py:202 -- The `process_trial_result` operation took 0.518 s, which may be a performance bottleneck.
# 2024-04-14 07:26:54,089	WARNING util.py:202 -- Processing trial results took 0.520 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 07:26:54,090	WARNING util.py:202 -- The `process_trial_result` operation took 0.521 s, which may be a performance bottleneck.
# 2024-04-14 07:27:05,821	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.502 s, which may be a performance bottleneck.
# 2024-04-14 07:27:05,823	WARNING util.py:202 -- The `process_trial_result` operation took 0.504 s, which may be a performance bottleneck.
# 2024-04-14 07:27:05,824	WARNING util.py:202 -- Processing trial results took 0.505 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 07:27:05,825	WARNING util.py:202 -- The `process_trial_result` operation took 0.507 s, which may be a performance bottleneck.
# 2024-04-14 07:31:43,713	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.533 s, which may be a performance bottleneck.
# 2024-04-14 07:31:43,715	WARNING util.py:202 -- The `process_trial_result` operation took 0.536 s, which may be a performance bottleneck.
# 2024-04-14 07:31:43,717	WARNING util.py:202 -- Processing trial results took 0.538 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 07:31:43,718	WARNING util.py:202 -- The `process_trial_result` operation took 0.539 s, which may be a performance bottleneck.
# 2024-04-14 07:32:16,734	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.502 s, which may be a performance bottleneck.
# 2024-04-14 07:32:16,735	WARNING util.py:202 -- The `process_trial_result` operation took 0.503 s, which may be a performance bottleneck.
# 2024-04-14 07:32:16,737	WARNING util.py:202 -- Processing trial results took 0.505 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 07:32:16,737	WARNING util.py:202 -- The `process_trial_result` operation took 0.505 s, which may be a performance bottleneck.
# 2024-04-14 07:33:15,372	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.532 s, which may be a performance bottleneck.
# 2024-04-14 07:33:15,374	WARNING util.py:202 -- The `process_trial_result` operation took 0.534 s, which may be a performance bottleneck.
# 2024-04-14 07:33:15,375	WARNING util.py:202 -- Processing trial results took 0.535 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 07:33:15,376	WARNING util.py:202 -- The `process_trial_result` operation took 0.536 s, which may be a performance bottleneck.
# 2024-04-14 07:33:35,923	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.532 s, which may be a performance bottleneck.
# 2024-04-14 07:33:35,925	WARNING util.py:202 -- The `process_trial_result` operation took 0.534 s, which may be a performance bottleneck.
# 2024-04-14 07:33:35,927	WARNING util.py:202 -- Processing trial results took 0.536 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 07:33:35,928	WARNING util.py:202 -- The `process_trial_result` operation took 0.537 s, which may be a performance bottleneck.
# 2024-04-14 07:34:07,864	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.510 s, which may be a performance bottleneck.
# 2024-04-14 07:34:07,866	WARNING util.py:202 -- The `process_trial_result` operation took 0.512 s, which may be a performance bottleneck.
# 2024-04-14 07:34:07,867	WARNING util.py:202 -- Processing trial results took 0.513 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 07:34:07,868	WARNING util.py:202 -- The `process_trial_result` operation took 0.514 s, which may be a performance bottleneck.
# 2024-04-14 07:34:32,851	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.513 s, which may be a performance bottleneck.
# 2024-04-14 07:34:32,853	WARNING util.py:202 -- The `process_trial_result` operation took 0.515 s, which may be a performance bottleneck.
# 2024-04-14 07:34:32,854	WARNING util.py:202 -- Processing trial results took 0.516 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 07:34:32,855	WARNING util.py:202 -- The `process_trial_result` operation took 0.517 s, which may be a performance bottleneck.
# 2024-04-14 07:35:02,813	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.501 s, which may be a performance bottleneck.
# 2024-04-14 07:35:02,815	WARNING util.py:202 -- The `process_trial_result` operation took 0.503 s, which may be a performance bottleneck.
# 2024-04-14 07:35:02,817	WARNING util.py:202 -- Processing trial results took 0.505 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 07:35:02,818	WARNING util.py:202 -- The `process_trial_result` operation took 0.506 s, which may be a performance bottleneck.
# 2024-04-14 07:36:22,275	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.549 s, which may be a performance bottleneck.
# 2024-04-14 07:36:22,277	WARNING util.py:202 -- The `process_trial_result` operation took 0.551 s, which may be a performance bottleneck.
# 2024-04-14 07:36:22,278	WARNING util.py:202 -- Processing trial results took 0.552 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 07:36:22,280	WARNING util.py:202 -- The `process_trial_result` operation took 0.553 s, which may be a performance bottleneck.
# 2024-04-14 07:39:30,316	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.503 s, which may be a performance bottleneck.
# 2024-04-14 07:39:30,318	WARNING util.py:202 -- The `process_trial_result` operation took 0.506 s, which may be a performance bottleneck.
# 2024-04-14 07:39:30,320	WARNING util.py:202 -- Processing trial results took 0.508 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 07:39:30,320	WARNING util.py:202 -- The `process_trial_result` operation took 0.508 s, which may be a performance bottleneck.
# 2024-04-14 07:40:46,752	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.502 s, which may be a performance bottleneck.
# 2024-04-14 07:40:46,754	WARNING util.py:202 -- The `process_trial_result` operation took 0.504 s, which may be a performance bottleneck.
# 2024-04-14 07:40:46,755	WARNING util.py:202 -- Processing trial results took 0.505 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 07:40:46,757	WARNING util.py:202 -- The `process_trial_result` operation took 0.507 s, which may be a performance bottleneck.
# 2024-04-14 07:43:39,341	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.538 s, which may be a performance bottleneck.
# 2024-04-14 07:43:39,343	WARNING util.py:202 -- The `process_trial_result` operation took 0.541 s, which may be a performance bottleneck.
# 2024-04-14 07:43:39,344	WARNING util.py:202 -- Processing trial results took 0.542 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 07:43:39,345	WARNING util.py:202 -- The `process_trial_result` operation took 0.543 s, which may be a performance bottleneck.
# 2024-04-14 07:44:07,602	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.529 s, which may be a performance bottleneck.
# 2024-04-14 07:44:07,605	WARNING util.py:202 -- The `process_trial_result` operation took 0.532 s, which may be a performance bottleneck.
# 2024-04-14 07:44:07,606	WARNING util.py:202 -- Processing trial results took 0.533 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 07:44:07,607	WARNING util.py:202 -- The `process_trial_result` operation took 0.534 s, which may be a performance bottleneck.
# 2024-04-14 07:44:51,709	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.511 s, which may be a performance bottleneck.
# 2024-04-14 07:44:51,711	WARNING util.py:202 -- The `process_trial_result` operation took 0.513 s, which may be a performance bottleneck.
# 2024-04-14 07:44:51,713	WARNING util.py:202 -- Processing trial results took 0.515 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 07:44:51,714	WARNING util.py:202 -- The `process_trial_result` operation took 0.516 s, which may be a performance bottleneck.
# 2024-04-14 07:44:58,965	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.507 s, which may be a performance bottleneck.
# 2024-04-14 07:44:58,967	WARNING util.py:202 -- The `process_trial_result` operation took 0.509 s, which may be a performance bottleneck.
# 2024-04-14 07:44:58,968	WARNING util.py:202 -- Processing trial results took 0.510 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 07:44:58,969	WARNING util.py:202 -- The `process_trial_result` operation took 0.511 s, which may be a performance bottleneck.
# 2024-04-14 07:45:20,987	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.538 s, which may be a performance bottleneck.
# 2024-04-14 07:45:20,989	WARNING util.py:202 -- The `process_trial_result` operation took 0.540 s, which may be a performance bottleneck.
# 2024-04-14 07:45:20,991	WARNING util.py:202 -- Processing trial results took 0.541 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 07:45:20,991	WARNING util.py:202 -- The `process_trial_result` operation took 0.542 s, which may be a performance bottleneck.
# 2024-04-14 07:45:42,198	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.505 s, which may be a performance bottleneck.
# 2024-04-14 07:45:42,201	WARNING util.py:202 -- The `process_trial_result` operation took 0.508 s, which may be a performance bottleneck.
# 2024-04-14 07:45:42,202	WARNING util.py:202 -- Processing trial results took 0.509 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 07:45:42,203	WARNING util.py:202 -- The `process_trial_result` operation took 0.510 s, which may be a performance bottleneck.
# 2024-04-14 07:46:34,107	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.520 s, which may be a performance bottleneck.
# 2024-04-14 07:46:34,109	WARNING util.py:202 -- The `process_trial_result` operation took 0.523 s, which may be a performance bottleneck.
# 2024-04-14 07:46:34,110	WARNING util.py:202 -- Processing trial results took 0.524 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 07:46:34,111	WARNING util.py:202 -- The `process_trial_result` operation took 0.525 s, which may be a performance bottleneck.
# 2024-04-14 07:47:32,623	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.503 s, which may be a performance bottleneck.
# 2024-04-14 07:47:32,625	WARNING util.py:202 -- The `process_trial_result` operation took 0.505 s, which may be a performance bottleneck.
# 2024-04-14 07:47:32,627	WARNING util.py:202 -- Processing trial results took 0.507 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 07:47:32,628	WARNING util.py:202 -- The `process_trial_result` operation took 0.508 s, which may be a performance bottleneck.
# 2024-04-14 07:47:55,406	WARNING util.py:202 -- The `callbacks.on_trial_result` operation took 0.513 s, which may be a performance bottleneck.
# 2024-04-14 07:47:55,408	WARNING util.py:202 -- The `process_trial_result` operation took 0.515 s, which may be a performance bottleneck.
# 2024-04-14 07:47:55,409	WARNING util.py:202 -- Processing trial results took 0.516 s, which may be a performance bottleneck. Please consider reporting results less frequently to Ray Tune.
# 2024-04-14 07:47:55,410	WARNING util.py:202 -- The `process_trial_result` operation took 0.517 s, which may be a performance bottleneck.
# 2024-04-14 07:49:20,746	INFO timeout.py:54 -- Reached timeout of 36000 seconds. Stopping all trials.
# 2024-04-14 07:49:34,178	INFO tune.py:1016 -- Wrote the latest version of all result files and experiment state to 'C:/Users/STEIM/ray_results/GA' in 13.3565s.
# 2024-04-14 07:49:34,772	INFO tune.py:1048 -- Total run time: 36014.25 seconds (36000.29 seconds for the tuning loop).
# 2024-04-14 07:50:06,543	WARNING experiment_analysis.py:190 -- Failed to fetch metrics for 1 trial(s):
# - train_b0bd1a85: FileNotFoundError('Could not fetch metrics for train_b0bd1a85: both result.json and progress.csv were not found at C:/Users/STEIM/ray_results/GA/train_b0bd1a85')

# %%
analysis.best_config
# Out:
# {'POP_SIZE': 500,
#  'INITIAL_MUTATION_RATE': 0.7070313584964933,
#  'FINAL_MUTATION_RATE': 0.18927695720161727,
#  'INITIAL_EXPLORATION': 0.9179428361908553,
#  'ELITISM': 0.8441423442813326,
#  'SURVIVAL_RATE': 0.4679128105055545}

# %%
tuning_history = (
    pd.concat(analysis.trial_dataframes, axis=0)
    .reset_index(drop=True)
    .filter(
        [
            "trial_id",
            "fitness",
            "training_iteration",
            "config/POP_SIZE",
            "config/INITIAL_MUTATION_RATE",
            "config/FINAL_MUTATION_RATE",
            "config/INITIAL_EXPLORATION",
            "config/ELITISM",
            "config/SURVIVAL_RATE",
        ]
    )
)

# Only keep the top combinations
num_best = 1000
top_combinations = tuning_history.groupby("trial_id").last().reset_index().sort_values("fitness", ascending=False).head(num_best)["trial_id"].to_list()
tuning_history = tuning_history.query("trial_id in @top_combinations")

# %%
(
    tuning_history
    .to_csv(
        f"./Tuning Results/{datetime.datetime.now().strftime('%Y%m%d%H%M')}_GA_Elite_numpy.csv",
        index=False,
    )
)
